# %% [markdown]
# **Swiggy Data Analysis**

# %% [markdown]
# **1) Business Objective**
#
# To assess and improve the quality, consistency, and completeness of the grocery product listing data by identifying anomalies, inconsistencies, missing information, duplicates, and pricing irregularities across products, categories, stores, and locations, thereby ensuring accurate product information and enhancing the customer shopping experience.

# %% [markdown]
# **2) Import Libraries**

# %%
import pandas as pd        # For data manipulation
import numpy as np      # For numerical computations
import seaborn as sns  # For advanced visualization
import matplotlib.pyplot as plt # For plotting
import re # For regular expressions

pd.set_option('display.max_colwidth', None)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# **3) Import Dataset**

# %%
df1 = pd.read_csv("/home/user/Downloads/2026-07-22/swiggy_instamart_2026_07_22.csv") 
df2 = pd.read_csv("/home/user/Downloads/2026-07-24/swiggy_instamart_2026_07_24.csv")
 #Reading Dataset from csv file

# %% [markdown]
# **4) Data Insights**

# %%
print("INFORMATION ABOUT DATASET 1")
print("--------------------------------")
df1.info()
# Out:
# INFORMATION ABOUT DATASET
# --------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117102 entries, 0 to 1117101
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   crawl_date_and_time      1117102 non-null  object
#  1   platform_name            1117102 non-null  object
#  2   store_id                 1117102 non-null  int64
#  3   store_name_location      1117102 non-null  object
#  4   city                     1117102 non-null  object
#  5   pin_code                 1117102 non-null  int64
#  6   unique_id                1117102 non-null  object
#  7   product_id_upc_ean       1117102 non-null  object
#  8   department               1117102 non-null  object
#  9   category                 1117102 non-null  object
#  10  sub_category             1117102 non-null  object
#  11  product_type             0 non-null        float64
#  12  brand_name               1116996 non-null  object
#  13  product_name             1117102 non-null  object
#  14  product_description      0 non-null        float64
#  15  product_grammage         1117102 non-null  object
#  16  package_type             0 non-null        float64
#  17  net_quantity             0 non-null        float64
#  18  variants                 1117102 non-null  object
#  19  item_mrp                 1117102 non-null  int64
#  20  item_selling_price       1117102 non-null  int64
#  21  out_of_stock_flag        1117102 non-null  object
#  22  discount_flag            1117102 non-null  object
#  23  product_price            1117102 non-null  int64
#  24  unit_price               0 non-null        float64
#  25  promo_offer_description  1117102 non-null  object
#  26  promo_offer_price        1117102 non-null  int64
#  27  discount_in_percent      1117102 non-null  int64
#  28  stock_count              1117102 non-null  int64
#  29  product_url              1117102 non-null  object
#  30  product_image_urls       1117102 non-null  object
# dtypes: float64(5), int64(8), object(18)
# memory usage: 264.2+ MB

# %%
print("INFORMATION ABOUT DATASET 2")
print("--------------------------------")
df2.info()
# Out:
# INFORMATION ABOUT DATASET 1
# --------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177307 entries, 0 to 1177306
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   crawl_date_and_time      1177307 non-null  object
#  1   platform_name            1177307 non-null  object
#  2   store_id                 1177307 non-null  int64
#  3   store_name_location      1177307 non-null  object
#  4   city                     1177307 non-null  object
#  5   pin_code                 1177307 non-null  int64
#  6   unique_id                1177307 non-null  object
#  7   product_id_upc_ean       1177307 non-null  object
#  8   department               1177307 non-null  object
#  9   category                 1177307 non-null  object
#  10  sub_category             1177307 non-null  object
#  11  product_type             0 non-null        float64
#  12  brand_name               1177112 non-null  object
#  13  product_name             1177307 non-null  object
#  14  product_description      0 non-null        float64
#  15  product_grammage         1177307 non-null  object
#  16  package_type             0 non-null        float64
#  17  net_quantity             0 non-null        float64
#  18  variants                 1177307 non-null  object
#  19  item_mrp                 1177307 non-null  int64
#  20  item_selling_price       1177307 non-null  int64
#  21  out_of_stock_flag        1177307 non-null  object
#  22  discount_flag            1177307 non-null  object
#  23  product_price            1177307 non-null  int64
#  24  unit_price               0 non-null        float64
#  25  promo_offer_description  1177307 non-null  object
#  26  promo_offer_price        1177307 non-null  int64
#  27  discount_in_percent      1177307 non-null  int64
#  28  stock_count              1177307 non-null  int64
#  29  product_url              1177307 non-null  object
#  30  product_image_urls       1177307 non-null  object
# dtypes: float64(5), int64(8), object(18)
# memory usage: 278.4+ MB

# %%
print("\nDESCRIPTIVE STATISTICS OF DATASET 1")
print("--------------------------------")
df1.describe().T.round(2)
# Out:
# DESCRIPTIVE STATISTICS OF DATASET 1
# --------------------------------
#                          count          mean           std        min  \
# store_id             1117102.0  1.396296e+06  3.059455e+04  1167234.0
# pin_code             1117102.0  5.223382e+05  1.688239e+05   110067.0
# product_type               0.0           NaN           NaN        NaN
# product_description        0.0           NaN           NaN        NaN
# package_type               0.0           NaN           NaN        NaN
# net_quantity               0.0           NaN           NaN        NaN
# item_mrp             1117102.0  7.494077e+08  8.169253e+10        1.0
# item_selling_price   1117102.0  7.494076e+08  8.169253e+10        1.0
# product_price        1117102.0  7.494076e+08  8.169253e+10        1.0
# unit_price                 0.0           NaN           NaN        NaN
# promo_offer_price    1117102.0  7.494076e+08  8.169253e+10        1.0
# discount_in_percent  1117102.0  1.514000e+01  1.506000e+01        0.0
# stock_count          1117102.0  1.660000e+00  2.590000e+00        0.0
#
#                            25%        50%        75%           max
# store_id             1401475.0  1403468.0  1404824.0  1.404890e+06
# pin_code              411033.0   560048.0   605009.0  8.420020e+05
# product_type               NaN        NaN        NaN           NaN
# product_description        NaN        NaN        NaN           NaN
# package_type               NaN        NaN        NaN           NaN
# net_quantity               NaN        NaN        NaN           NaN
# item_mrp                 109.0      225.0      435.0  8.906005e+12
# item_selling_price        90.0      185.0      360.0  8.906005e+12
# product_price             90.0      185.0      360.0  8.906005e+12
# unit_price                 NaN        NaN        NaN           NaN
# promo_offer_price         90.0      185.0      360.0  8.906005e+12
# discount_in_percent        2.0       11.0       23.0  9.200000e+01
# stock_count                0.0        1.0        2.0  7.800000e+01

# %%
print("\nDESCRIPTIVE STATISTICS OF DATASET 2")
print("--------------------------------")
df2.describe().T.round(2)
# Out:
# DESCRIPTIVE STATISTICS OF DATASET 2
# --------------------------------
#                          count          mean           std       min  \
# store_id             1177307.0  1.339485e+06  1.697580e+05  406774.0
# pin_code             1177307.0  1.137921e+05  5.553440e+03  110005.0
# product_type               0.0           NaN           NaN       NaN
# product_description        0.0           NaN           NaN       NaN
# package_type               0.0           NaN           NaN       NaN
# net_quantity               0.0           NaN           NaN       NaN
# item_mrp             1177307.0  7.262140e+08  8.041853e+10       0.0
# item_selling_price   1177307.0  7.262140e+08  8.041853e+10       0.0
# product_price        1177307.0  7.262140e+08  8.041853e+10       0.0
# unit_price                 0.0           NaN           NaN       NaN
# promo_offer_price    1177307.0  7.262140e+08  8.041853e+10       0.0
# discount_in_percent  1177307.0  1.505000e+01  1.539000e+01       0.0
# stock_count          1177307.0  1.670000e+00  2.410000e+00       0.0
#
#                            25%        50%        75%           max
# store_id             1384513.0  1400547.0  1403179.0  1.405027e+06
# pin_code              110042.0   110080.0   122003.0  1.225050e+05
# product_type               NaN        NaN        NaN           NaN
# product_description        NaN        NaN        NaN           NaN
# package_type               NaN        NaN        NaN           NaN
# net_quantity               NaN        NaN        NaN           NaN
# item_mrp                 108.0      219.0      425.0  8.906005e+12
# item_selling_price        90.0      180.0      357.0  8.906005e+12
# product_price             90.0      180.0      357.0  8.906005e+12
# unit_price                 NaN        NaN        NaN           NaN
# promo_offer_price         90.0      180.0      357.0  8.906005e+12
# discount_in_percent        1.0       11.0       23.0  9.200000e+01
# stock_count                0.0        1.0        2.0  5.000000e+01

# %%
print("\nDATASET1 SHAPE")
print("--------------------------------")
print("The shape =", df1.shape)
num_rows, num_cols = df1.shape
num_features = num_cols - 1
num_data = num_rows * num_cols

# Print the information about the dataset
print(f"Number of Rows: {num_rows}")
print(f"Number of Columns: {num_cols}")
print(f"Number of Features: {num_features}")
print(f"Number of All Data: {num_data}")
# Out:
# DATASET1 SHAPE
# --------------------------------
# The shape = (1117102, 31)
# Number of Rows: 1117102
# Number of Columns: 31
# Number of Features: 30
# Number of All Data: 34630162

# %%
print("\nDATASET 2 SHAPE")
print("--------------------------------")
print("The shape =", df2.shape)
num_rows, num_cols = df2.shape
num_features = num_cols - 1
num_data = num_rows * num_cols

# Print the information about the dataset
print(f"Number of Rows: {num_rows}")
print(f"Number of Columns: {num_cols}")
print(f"Number of Features: {num_features}")
print(f"Number of All Data: {num_data}")
# Out:
# DATASET 2 SHAPE
# --------------------------------
# The shape = (1177307, 31)
# Number of Rows: 1177307
# Number of Columns: 31
# Number of Features: 30
# Number of All Data: 36496517

# %%
print("COLUMNWISE DATA1 PROFILING")
print("--------------------------------")
summary = []

for col in df1.columns:
    null_count = df1[col].isnull().sum()
    null_percent = round((null_count / len(df1)) * 100, 2)
    distinct_count = df1[col].nunique(dropna=True)

    # Check if all non-null values are unique
    is_unique = "Yes" if df1[col].is_unique and null_count == 0 else "No"


    summary.append({
        'column_name': col,
        'null_count': null_count,
        #'null_percent': null_percent,
        'distinct_count': distinct_count,
        'is_unique': is_unique
    })

summary_df = pd.DataFrame(summary)

# Display the summary
print(summary_df)
# Out:
# COLUMNWISE DATA1 PROFILING
# --------------------------------
#                 column_name  null_count  distinct_count is_unique
# 0       crawl_date_and_time           0            5669        No
# 1             platform_name           0               1        No
# 2                  store_id           0             116        No
# 3       store_name_location           0             100        No
# 4                      city           0              47        No
# 5                  pin_code           0              96        No
# 6                 unique_id           0          901907        No
# 7        product_id_upc_ean           0           30181        No
# 8                department           0               9        No
# 9                  category           0              16        No
# 10             sub_category           0             148        No
# 11             product_type     1117102               0        No
# 12               brand_name         106            2676        No
# 13             product_name           0           30744        No
# 14      product_description     1117102               0        No
# 15         product_grammage           0            2048        No
# 16             package_type     1117102               0        No
# 17             net_quantity     1117102               0        No
# 18                 variants           0            8128        No
# 19                 item_mrp           0            1720        No
# 20       item_selling_price           0            2111        No
# 21        out_of_stock_flag           0               2        No
# 22            discount_flag           0               2        No
# 23            product_price           0            2111        No
# 24               unit_price     1117102               0        No
# 25  promo_offer_description           0              90        No
# 26        promo_offer_price           0            2111        No
# 27      discount_in_percent           0              90        No
# 28              stock_count           0              56        No
# 29              product_url           0           30181        No
# 30       product_image_urls           0           33952        No

# %%
print("COLUMNWISE DATA2 PROFILING")
print("--------------------------------")
summary = []

for col in df2.columns:
    null_count = df2[col].isnull().sum()
    null_percent = round((null_count / len(df2)) * 100, 2)
    distinct_count = df2[col].nunique(dropna=True)

    # Check if all non-null values are unique
    is_unique = "Yes" if df2[col].is_unique and null_count == 0 else "No"


    summary.append({
        'column_name': col,
        'null_count': null_count,
        #'null_percent': null_percent,
        'distinct_count': distinct_count,
        'is_unique': is_unique
    })

summary_df = pd.DataFrame(summary)

# Display the summary
print(summary_df)
# Out:
# COLUMNWISE DATA2 PROFILING
# --------------------------------
#                 column_name  null_count  distinct_count is_unique
# 0       crawl_date_and_time           0            6939        No
# 1             platform_name           0               1        No
# 2                  store_id           0             100        No
# 3       store_name_location           0              98        No
# 4                      city           0               2        No
# 5                  pin_code           0              56        No
# 6                 unique_id           0          954138        No
# 7        product_id_upc_ean           0           23419        No
# 8                department           0               9        No
# 9                  category           0              16        No
# 10             sub_category           0             147        No
# 11             product_type     1177307               0        No
# 12               brand_name         195            1975        No
# 13             product_name           0           24013        No
# 14      product_description     1177307               0        No
# 15         product_grammage           0            1864        No
# 16             package_type     1177307               0        No
# 17             net_quantity     1177307               0        No
# 18                 variants           0            7151        No
# 19                 item_mrp           0            1547        No
# 20       item_selling_price           0            1768        No
# 21        out_of_stock_flag           0               2        No
# 22            discount_flag           0               2        No
# 23            product_price           0            1768        No
# 24               unit_price     1177307               0        No
# 25  promo_offer_description           0              90        No
# 26        promo_offer_price           0            1768        No
# 27      discount_in_percent           0              90        No
# 28              stock_count           0              51        No
# 29              product_url           0           23419        No
# 30       product_image_urls           0           25797        No

# %%
store_list1 = set(df1['store_id'].unique())
store_list2 = set(df2['store_id'].unique())

print("Stores in first list, not in second list:")
print(list(store_list1 - store_list2))
print(len(list(store_list1 - store_list2)))

print("\nStores in second list, not in first list:")
print(list(store_list2 - store_list1))
print(len(list(store_list2 - store_list1)))

print("\nStores common in both lists:")
print(list(store_list1 & store_list2))
print(len(list(store_list1 & store_list2)))
# Out:
# Stores in first list, not in second list:
# [1399810, 1395729, 1396293, 1403468, 1402445, 1400930, 1401475, 1390216, 1403021, 1402070, 1391901, 1397057, 1403723, 1388389, 1404781, 1382254, 1404783, 1382255, 1404784, 1401714, 1404785, 1404786, 1404788, 1404787, 1404791, 1404792, 1404789, 1404794, 1404795, 1404790, 1404796, 1404797, 1404798, 1404800, 1404799, 1167234, 1404802, 1169284, 1404804, 1404808, 1404809, 1404811, 1404816, 1392529, 1386385, 1392531, 1386386, 1402771, 1382290, 1402770, 1402774, 1402775, 1402773, 1402778, 1402780, 1402781, 1402782, 1404824, 1402784, 1404830, 1402786, 1402787, 1402788, 1402789, 1402790, 1404834, 1404835, 1388452, 1388451, 1404838, 1402796, 1404843, 1404841, 1404844, 1402801, 1402802, 1402803, 1396660, 1404849, 1402805, 1402806, 1388453, 1402807, 1402808, 1404850, 1404855, 1404856, 1404858, 1404859, 1404860, 1404864, 1404866, 1404867, 1404868, 1404869, 1404875, 1404876, 1404877, 1404878, 1382349, 1382352, 1382353, 1404881, 1382350, 1386448, 1382351, 1404884, 1386449, 1404886, 1382354, 1386450, 1404890, 1394684, 1399806]
# 114
#
# Stores in second list, not in first list:
# [1062419, 1062420, 1404450, 1230886, 1386535, 1386536, 1384511, 1389633, 1384513, 1405012, 1402457, 1400924, 1382494, 1405027, 649841, 1389689, 1389690, 649851, 1239163, 1401469, 1062023, 1400967, 1388689, 1404576, 1404584, 1229997, 1404592, 1404596, 762550, 1398454, 1387704, 1387705, 762551, 1404604, 1099457, 1099458, 1099459, 1404610, 1402053, 1404613, 1402052, 1402055, 1402056, 1404620, 1267917, 1384143, 1278169, 1386719, 1400547, 1400548, 1395428, 1400549, 1402607, 1402608, 1402609, 406774, 1404675, 1382659, 1404165, 1380623, 1394450, 1261842, 1394451, 1386271, 1397028, 1403179, 1403184, 1401649, 1401654, 1380671, 1403206, 1403207, 1403208, 1403213, 1404755, 1404770, 810368, 1402248, 1402249, 1402253, 1399699, 1399700, 1383827, 1402777, 1401254, 1383851, 1403311, 1386943, 1386948, 1381835, 1389006, 1404879, 1392083, 1382871, 1383383, 1385945, 1398755, 1398757]
# 98
#
# Stores common in both lists:
# [1404888, 1382258]
# 2

# %%
df1.store_id.unique()
print(len(df1.store_id.unique()))
print(len(df1.store_name_location.unique()))
# Out:
# 116
# 100

# %%
df2.store_id.unique()
print(len(df2.store_id.unique()))
print(len(df2.store_name_location.unique()))
# Out:
# 100
# 98

# %%
store_mapping = (
    df2.groupby('store_name_location')['store_id']
      .nunique()
      .reset_index(name='unique_store_ids')
      .sort_values('unique_store_ids', ascending=False)
)

multi_store = store_mapping[store_mapping['unique_store_ids'] > 1]

print(multi_store)
print("\nNumber of store_name_location with multiple store_ids:", len(multi_store))
# Out:
#                                                                                                                                                 store_name_location  \
# 13                                                                                                      47C, Phase, 1, Mayur Vihar, New Delhi, Delhi, 110091, India
# 55                                                                                     Jharsa Road, UniTech Cyber Park, Jharsa Rd, Gurugram, Haryana, 122001, India
# 62                                   Mahesh Cycle Works, RZ-194, Harfool Singh Market, Jivan Park, Main Bindapur Rd, Indira Park, Uttam Nagar, Delhi, 110059, India
# 33                                                                          Boom Plaza, Mall, Block C, Sushant Lok III, Sector 57, Gurugram, Haryana, 122011, India
# 37                                                     DCB Bank ATM, D.B. Gupta Road, Karol Bagh, Opposite Pind Baluchi, Block 57, Karol Bagh, Delhi, 110005, India
# 76                                                     Roomshala 140 Hotel 24&7 Malviya Nagar, 45, Sri Aurobindo LN, Malviya Nagar, New Delhi, Delhi, 110017, India
# 26                                             Ather Grid Charging Station, Anil Kumar, Parsvnath Exotica, DLF Phase 5, Sector 53, Gurugram, Haryana, 122003, India
# 78                                                                              SRS Cinemas, Reach 2, Block-S, Block S, Sector 49, Gurugram, Haryana, 122018, India
# 42                                           Detailing Bull Gurugram, F7, Near Hong Kong Bazar, Block F, Sushant Lok 2, Sector 57, Gurugram, Haryana, 122011, India
# 22                                                                            Aadhar Card Center, Vir Banda Bairagi Marg, Inderlok, New Delhi, Delhi, 110052, India
# 81                                                                       Samvit Hospital Parking, 02, Islampur Village, Sector 38, Gurugram, Haryana, 122005, India
# 82                                              Sara Mart, Sector-52, Ardee City Gate Number 2 Rd, Sarswati Kunj II, Wazirabad, 4, Gurugram, Haryana, 122003, India
# 83                                                                                                   Sector 12, Rama Krishna Puram, New Delhi, Delhi, 110022, India
# 35                                                        CIFAR Fertility & IVF Centre, Plot No. 561P, 2nd & 3rd Floor, Sector 27, Gurugram, Haryana, 122009, India
# 16                                                       528/1, Shitala Mata Mandir Marg, Sheetla Colony Phase 2, Sheetala Colony, Gurugram, Haryana, 122017, India
# 70                                                                                 Phase 1, C 933, Sushant Lok Phase I, Sector 43, Gurugram, Haryana, 122009, India
# 46    Gali No - 2, East Guru Angad Nagar, Tooth Spa Implant Dental Clinic, 10A, Street No 2, East Guru Angad Nagar, Swasthya Vihar, New Delhi, Delhi, 110051, India
# 48  Her Fitness Kirti Nagar - Ladies Gym In Kirti Nagar, Delhi, 42, Basement, Opp. Singh Chicken, DLE Industrial Area, Kirti Nagar, New Delhi, Delhi, 110015, India
# 54                                                     JM Jain, 9A, 23, W.E.A Brahampuri, Channa Market, Block 9A, WEA, Karol Bagh, New Delhi, Delhi, 110005, India
# 95                                                                                     Vikaspuri Road, Vikaspuri Rd, Manohar Nagar, Vikaspuri, Delhi, 110018, India
# 51                                                      Hotel Wedlock Premium, Plot No. 235, Medicity, Islampur Colony, Sector 38, Gurugram, Haryana, 122005, India
# 7                                                                                                  1713, Sector 32A Rd, Sector 31, Gurugram, Haryana, 122001, India
# 93        VLCC Beauty Clinic (Sohna Road, Gurgaon), Shop No, 22, Badshahpur Sohna Rd Hwy, Vatika City, Block W, Market, Sector 49, Gurugram, Haryana, 122018, India
#
#     unique_store_ids
# 13                 3
# 55                 2
# 62                 2
# 33                 2
# 37                 2
# 76                 2
# 26                 2
# 78                 2
# 42                 2
# 22                 2
# 81                 2
# 82                 2
# 83                 2
# 35                 2
# 16                 2
# 70                 2
# 46                 2
# 48                 2
# 54                 2
# 95                 2
# 51                 2
# 7                  2
# 93                 2
#
# Number of store_name_location with multiple store_ids: 23

# %% [markdown]
# ***Insights :***
# _______________
#     * Shape of the dataset is 12,42,276 X 31
#     * None of the columns is having unique values.
#     * 'product_type', 'product_description', 'package_type', 'net_quantity', 'unit_price' are completely null columns.
#     * 'brand_name' is a partialy null column with 170 null values.
#     * Distinct store_id and store_name_location count are 125 and 100 respectively. While ivestigating, we found that 28 store_name_locations have exactly two store_ids each.

# %% [markdown]
# **5) Primary key Analysis**

# %% [markdown]
# As per the above informations, no column can be choose as primary key.

# %%
# Check if the combination is unique
is_unique = not df2.duplicated(subset=['unique_id', 'store_id','product_id_upc_ean', 'product_name']).any()

print("Is (unique_id, store_id, product_id_upc_ean, product_name) combination unique?", is_unique)
# Out:
# Is (unique_id, store_id, product_id_upc_ean, product_name) combination unique? False

# %% [markdown]
# Checked several combinations, but couldn't fix a unique combination

# %% [markdown]
# **6) Duplicate Analysis**

# %%
print("EXACT DUPLICATE ROWS")
print("--------------------------------")
exact_duplicate_count = df2.duplicated().sum()
print("Exact duplicate rows:", exact_duplicate_count)


print("\nDUPLICATE PRODUCTS IN THE SAME STORE")
print("--------------------------------")
product_duplicate_count = df2.duplicated(
    subset=['store_id', 'product_name']
).sum()

print(f"\nNumber of duplicate products (store_id + product_name): {product_duplicate_count}")


print("\n========== DUPLICATE ANALYSIS SUMMARY ==========")
print(f"Total Rows                  : {len(df2)}")
print(f"Exact Duplicate Rows        : {exact_duplicate_count}")
print(f"Product Duplicate Rows      : {product_duplicate_count}")
print("================================================")
# Out:
# EXACT DUPLICATE ROWS
# --------------------------------
# Exact duplicate rows: 0
#
# DUPLICATE PRODUCTS IN THE SAME STORE
# --------------------------------
#
# Number of duplicate products (store_id + product_name): 286590
#
# ========== DUPLICATE ANALYSIS SUMMARY ==========
# Total Rows                  : 1177307
# Exact Duplicate Rows        : 0
# Product Duplicate Rows      : 286590
# ================================================

# %%
# checking for duplicate combinations of store_name_location, product_name, product_grammage, item_selling_price and package_type
dup_products = (
    df2.groupby([
        'store_name_location',
        'product_name',
        'product_grammage',
        'item_selling_price',
        'package_type'
    ])
    .size()
    .reset_index(name='count')
)

dup_products = dup_products[dup_products['count'] > 1]\
                    .sort_values('count', ascending=False)

print("Duplicate combinations:", len(dup_products))
print(dup_products.head(20))
# Out:
# Duplicate combinations: 0
# Empty DataFrame
# Columns: [store_name_location, product_name, product_grammage, item_selling_price, package_type, count]
# Index: []

# %%
# Check for products mapped to multiple categories
product_category_check = (
    df2.groupby(['store_name_location', 'product_name','product_grammage', 'product_url','package_type'])['category']
      .nunique()
      .reset_index(name='category_count')
)

# Products mapped to more than one category
inconsistent_products = product_category_check[
    product_category_check['category_count'] > 1
].sort_values('category_count', ascending=False)

print("Number of inconsistent products:",
      len(inconsistent_products))

print(inconsistent_products.head())
print("\nNumber of inconsistent products:", len(inconsistent_products))
# Out:
# Number of inconsistent products: 0
# Empty DataFrame
# Columns: [store_name_location, product_name, product_grammage, product_url, package_type, category_count]
# Index: []
#
# Number of inconsistent products: 0

# %%
# Check for products mapped to multiple sub_categories
product_category_check = (
    df2.groupby(['store_name_location', 'product_name','product_grammage', 'product_url','package_type'])['sub_category']
      .nunique()
      .reset_index(name='sub_category_count')
)

# Products mapped to more than one category
inconsistent_products = product_category_check[
    product_category_check['sub_category_count'] > 1
].sort_values('sub_category_count', ascending=False)

print("Number of inconsistent products:",
      len(inconsistent_products))

print(inconsistent_products.head())
print("\nNumber of inconsistent products:", len(inconsistent_products))
# Out:
# Number of inconsistent products: 0
# Empty DataFrame
# Columns: [store_name_location, product_name, product_grammage, product_url, package_type, sub_category_count]
# Index: []
#
# Number of inconsistent products: 0

# %%
# Count distinct product names for each unique_id
product_name_counts = (
    df2.groupby("unique_id")["product_name"]
      .nunique(dropna=False)
)

# unique_id values having more than one product_name
duplicate_unique_ids = product_name_counts[product_name_counts > 1].index

print(f"Number of unique_id values with different product_name: {len(duplicate_unique_ids)}")
print(duplicate_unique_ids.tolist())
# Out:
# Number of unique_id values with different product_name: 0
# []

# %% [markdown]
# ***Insights :***
# ___________________
#
#     * No exact duplicate columns exists on the dataset, but products duplicates on same stores
#     * While deeply investigating, these duplicate products differ by grammage, price or package_type.
#     * Also confirmed no products duplicates on same store under different categories.
#     * In overall, the dataset is not containing duplicate products visibly.

# %% [markdown]
# 7) MISSING VALUE ANALYSIS

# %% [markdown]
# As mentioned some columns are completely null, that not need to be evaluated. brand_name column is partially null with 170 null values. Lets evaluate that.

# %%
# Missing summary by store
print("\nMISSING SUMMARY BY STORE")
print("--------------------------------")
missing_by_store = df2.groupby('store_name_location')['brand_name'].apply(
    lambda x: x.isnull().mean() * 100
).reset_index()

print(missing_by_store)
# Out:
# MISSING SUMMARY BY STORE
# --------------------------------
#                                                                                                                                           store_name_location  \
# 0                                                                           1, Asaf Ali Rd, Near DDA Complex, Kalyanpura, Chandni Chowk, Delhi, 110006, India
# 1                                                 1, Dwarka Goyla Dairy Rd, Near Goyla More, Deenpur, Surya Vihar, Najafgarh, New Delhi, Delhi, 110043, India
# 2                                                                       112, North, Block-RZ-D, Mahavir Enclave Part 2, Mahavir Enclave, Delhi, 110059, India
# 3                                                                                 1231, C2 Internal Rd, Block C 2, Sector 3, Gurugram, Haryana, 122017, India
# 4                                                                         13 J-13/14, Block J, Rajouri Garden Extension, Rajouri Garden, Delhi, 110027, India
# ..                                                                                                                                                        ...
# 93  VLCC Beauty Clinic (Sohna Road, Gurgaon), Shop No, 22, Badshahpur Sohna Rd Hwy, Vatika City, Block W, Market, Sector 49, Gurugram, Haryana, 122018, India
# 94                                                          Velogic India, 90, Bijwasan Rd, Kapas Hera Extension, Kapas Hera, New Delhi, Delhi, 110037, India
# 95                                                                               Vikaspuri Road, Vikaspuri Rd, Manohar Nagar, Vikaspuri, Delhi, 110018, India
# 96                                            Vishal Cinema Road, Vishal Cinema Rd, Pocket GN, Shivaji Enclave, Tagore Garden Extension, Delhi, 110027, India
# 97                                                                                              WZ-265, Palam Village, Palam, New Delhi, Delhi, 110045, India
#
#     brand_name
# 0     0.017027
# 1     0.017201
# 2     0.021354
# 3     0.030143
# 4     0.011696
# ..         ...
# 93    0.021927
# 94    0.023410
# 95    0.024526
# 96    0.022247
# 97    0.011075
#
# [98 rows x 2 columns]

# %%
# Missing summary by category
print("\nMISSING SUMMARY BY CATEGORY")
print("--------------------------------")
missing_by_category = df2.groupby('category')['brand_name'].apply(
    lambda x: x.isnull().mean() * 100
).reset_index()

print(missing_by_category)
# Out:
# MISSING SUMMARY BY CATEGORY
# --------------------------------
#                           category  brand_name
# 0               Atta, Rice and Dal    0.180949
# 1                        Baby Care    0.000000
# 2                    Bath and Body    0.000000
# 3               Biscuits and Cakes    0.000000
# 4            Cereals and Breakfast    0.000000
# 5               Chips and Namkeens    0.000000
# 6                       Chocolates    0.000000
# 7           Cold Drinks and Juices    0.000000
# 8            Dairy, Bread and Eggs    0.000000
# 9                 Feminine Hygiene    0.000000
# 10                       Hair Care    0.000000
# 11  Ice Creams and Frozen Desserts    0.022929
# 12                          Makeup    0.084893
# 13                     Paan Corner    0.000000
# 14                        Skincare    0.000000
# 15                    Sweet Corner    0.000000

# %%
print("\nMISSING SUMMARY BY CITY")
print("--------------------------------")

missing_by_city = df2.groupby('city')['brand_name'].apply(
    lambda x: x.isnull().mean() * 100
).reset_index()

print(missing_by_city)
# Out:
# MISSING SUMMARY BY CITY
# --------------------------------
#       city  brand_name
# 0    Delhi    0.015927
# 1  Gurgaon    0.017967

# %% [markdown]
# ***Insights :***
# _______________
#
#     * In store-wise, missing values are almost equally distributed.
#     * In category-wise also mising percentage is below 0.2, which is negliglible.
#     * In city-wise too, the missing percentage has no hike at any particular city.
#     * So in overall missing% doesn't have any direct impact form store/category/city.

# %% [markdown]
# **8) Category Hierarchy Consistency**

# %%
print("\n DEPARTMENT - CATEGORY CONSISTENCY")
print("--------------------------------")

dept_category_map = df2.groupby('department')['category'].unique()

for dept, cats in dept_category_map.items():
    print("\nDEPARTMENT:", dept)
    print(list(cats))
# Out:
#  DEPARTMENT - CATEGORY CONSISTENCY
# --------------------------------
#
# DEPARTMENT: Atta, Rice & Dal
# ['Atta, Rice and Dal']
#
# DEPARTMENT: Baby Care
# ['Baby Care']
#
# DEPARTMENT: Bakery & Biscuits
# ['Biscuits and Cakes']
#
# DEPARTMENT: Beauty & Cosmetics
# ['Bath and Body', 'Makeup', 'Hair Care']
#
# DEPARTMENT: Cold Drinks & Juices
# ['Cold Drinks and Juices']
#
# DEPARTMENT: Dairy & Breakfast
# ['Cereals and Breakfast', 'Dairy, Bread and Eggs']
#
# DEPARTMENT: Munchies
# ['Chips and Namkeens', 'Cereals and Breakfast']
#
# DEPARTMENT: Personal Care
# ['Bath and Body', 'Skincare', 'Feminine Hygiene', 'Hair Care', 'Makeup']
#
# DEPARTMENT: Sweet Tooth
# ['Chocolates', 'Ice Creams and Frozen Desserts', 'Sweet Corner', 'Paan Corner']

# %%
print("\n CATEGORY - SUBCATEGORY CONSISTENCY")
print("--------------------------------")

cat_subcat_map = df2.groupby('category')['sub_category'].unique()

for cat, subcats in cat_subcat_map.items():
    print("\nCATEGORY:", cat)
    print(list(subcats))
# Out:
#  CATEGORY - SUBCATEGORY CONSISTENCY
# --------------------------------
#
# CATEGORY: Atta, Rice and Dal
# ['Besan, Sooji and Maida', 'Other Flours', 'Millets & Daliya', 'Atta', 'Poha & Puffed Rice', 'Rajma, Chola and Others', 'Toor, Moong and Urad', 'Rice']
#
# CATEGORY: Baby Care
# ['Clothes & Accessories', 'Travel Needs & Baby Gears', 'Baby Food and Formula', 'Gifts & More', 'Books and Toys', 'Baby Wipes', 'Baby Bathing', 'Feeding and Teething Needs', 'Baby Pharma', 'Baby Diapers', 'Mom Care', 'Baby Hygiene', 'Baby Oral Care', 'Baby Oil and Talc', 'Baby Cream & Lotions']
#
# CATEGORY: Bath and Body
# ['Body Lotion & Oils', 'Face Care', 'Fragrance & Talc', 'Mens Perfume', 'Womens Perfume', 'Bath & Beauty gifts', 'Lip care', 'Soaps', 'Roll on', 'Shower gel', 'Bath Accessories', 'Oral care', 'Handwash', 'Multi groomers']
#
# CATEGORY: Biscuits and Cakes
# ['Baking Ingredients', 'Cookies', 'Cream Biscuits', 'Gourmet collection', 'Marie & Digestive', 'Healthy Snacking', 'Rusk', 'Wafers', 'Salted & Plain', 'Gift Boxes', 'Cakes & Pies']
#
# CATEGORY: Cereals and Breakfast
# ['Batters', 'Ready Mixes', 'Pancake Mixes', 'Seeds and trail Mixes', 'Kids Cereals', 'Muesli & Granola', 'Oats', 'Peanut Butters', 'Energy Bars', 'Flakes']
#
# CATEGORY: Chips and Namkeens
# ['Bhujia and Namkeens', 'Makhana & Dry Fruits', 'Gift Hampers', 'Nachos', 'Popcorn', 'Chips and Crisps']
#
# CATEGORY: Chocolates
# ['Gums & Mint', 'Gift Boxes', 'Premium', 'Wafers', 'Shared Packs', 'Gourmet collection', 'Kunafa Chocolate', 'Dark Chocolates', 'Milk Chocolates', 'Candies & More']
#
# CATEGORY: Cold Drinks and Juices
# ['Coconut Water', 'Cold Coffee', 'Milk Based Drinks', 'Ice Tea & Kombucha', 'Energy Drinks', 'Juices and Fruit Drinks', 'Mango Drinks', 'Fresh Juices', 'Soda and Mixers', 'Soft Drinks', 'Water and Ice Cubes']
#
# CATEGORY: Dairy, Bread and Eggs
# ['Bread and Buns', 'Butter', 'Cheese', 'Cream and Condensed Milk', 'Curd and Yogurts', 'Milkshakes and More', 'Lassi and Buttermilk', 'Milk', 'Paneer and Tofu', 'Eggs']
#
# CATEGORY: Feminine Hygiene
# ['Sanitary Pads', 'Period Panties and Liners', 'Hair Removal', 'Menstrual Cups and Tampons', 'Intimate Wipes and Wash', 'Disposal Bags and Cramp Relief']
#
# CATEGORY: Hair Care
# ['Hair Styling Gels & Creams', 'Hair Oils and Serums', 'Conditioners & Masks', 'Hair Colour', 'Hair Dryers and Stylers', 'Shampoo', 'Premium Brands', 'Combs & Brushes', 'Hair Supplements']
#
# CATEGORY: Ice Creams and Frozen Desserts
# ['Guiltfree', 'Real Fruit', 'Tubs & Party Packs', 'Cones', 'Cups', 'Gourmet', 'Kulfi', 'Premium', 'Sticks', 'Cakes & Sandwiches', 'Rare Finds', 'Syrups', 'Regional Favorites']
#
# CATEGORY: Makeup
# ['Eyes', 'Face', 'Tools & Brushes', 'Eye lens', 'Lips', 'Nails']
#
# CATEGORY: Paan Corner
# ['Paan and Mouth Fresheners', 'Gum and Mint']
#
# CATEGORY: Skincare
# ['Creams & Moisturizers', 'Masks & Cleansers', 'Face wash and scrubs', 'Sunscreen', 'Serums, Toners', 'Body Lotions', 'Beauty Supplements']
#
# CATEGORY: Sweet Corner
# ['Chikki', 'Gulkand & Paan', 'Cream Biscuits', 'Chocofills', 'Cakes and Pies', 'Gulab Jamun', 'Ladoos', 'Dry Fruit Sweets', 'Pedhas', 'Rasgulla', 'Kaju Katli & Barfi', 'Dessert Mixes', 'Mysore Pak', 'Rasmalai']

# %% [markdown]
# ***Insights :***
# ___________________
#
#     * No specific inconsistencies noticed accross department-category or category-subcategory combinations

# %% [markdown]
# **9) Suspicious Value Checking**

# %%
def find_suspicious_values(df, column_name):
    suspicious_values = [
        'null', 'none', 'n/a', 'na', 'nil', 'not available',
        'not applicable', '-', '--', '0', ''
    ]
    
    mask = (
        df1[column_name].isna() |
        df1[column_name].astype(str).str.strip().str.lower().isin(suspicious_values) |
        df1[column_name].str.fullmatch(r'\d+') |   # numeric only
        (df1[column_name].str.len() < 3)    # too short
        )
    
    df_suspicious = df1[mask]
    print(f"Number of suspicious values in '{column_name}': {len(df_suspicious)}")
    return df_suspicious[column_name].unique()

print(find_suspicious_values(df1, 'product_name'))
print(find_suspicious_values(df1, 'brand_name'))
print(find_suspicious_values(df1, 'store_name_location'))
print(find_suspicious_values(df1, 'department'))
print(find_suspicious_values(df1, 'category'))
print(find_suspicious_values(df1, 'sub_category'))
# Out:
# Number of suspicious values in 'product_name': 0
# []
# Number of suspicious values in 'brand_name': 3073
# ['RG' '921' nan 'Yu' 'He' 'Go' 'SS' 'Jo' 'P']
# Number of suspicious values in 'store_name_location': 0
# []
# Number of suspicious values in 'department': 0
# []
# Number of suspicious values in 'category': 0
# []
# Number of suspicious values in 'sub_category': 0
# []

# %%
def find_suspicious_values(df, column_name):
    suspicious_values = [
        'null', 'none', 'n/a', 'na', 'nil', 'not available',
        'not applicable', '-', '--', '0', ''
    ]
    
    mask = (
        df2[column_name].isna() |
        df2[column_name].astype(str).str.strip().str.lower().isin(suspicious_values) |
        df2[column_name].str.fullmatch(r'\d+') |   # numeric only
        (df2[column_name].str.len() < 3)    # too short
        )
    
    df_suspicious = df2[mask]
    print(f"Number of suspicious values in '{column_name}': {len(df_suspicious)}")
    return df_suspicious[column_name].unique()

print(find_suspicious_values(df2, 'product_name'))
print(find_suspicious_values(df2, 'brand_name'))
print(find_suspicious_values(df2, 'store_name_location'))
print(find_suspicious_values(df2, 'department'))
print(find_suspicious_values(df2, 'category'))
print(find_suspicious_values(df2, 'sub_category'))
# Out:
# Number of suspicious values in 'product_name': 0
# []
# Number of suspicious values in 'brand_name': 3523
# [nan '921' 'Yu' 'Go' 'Jo' 'P' 'He' 'SP']
# Number of suspicious values in 'store_name_location': 0
# []
# Number of suspicious values in 'department': 0
# []
# Number of suspicious values in 'category': 0
# []
# Number of suspicious values in 'sub_category': 0
# []

# %%
 #Check for numeric columns that should not have negative values or zero

numeric_columns = ['store_id','pin_code','unique_id','product_grammage','net_quantity', 'item_mrp','item_selling_price', 'product_price','promo_offer_price','discount_in_percent','stock_count']

print("Checking price field separators (should use dot '.' not comma ','):\n")

for col in numeric_columns:
    if col in df1.columns:
        # Find rows with comma in price field
        comma_values = df1[df1[col].astype(str).str.contains(',', na=False)]
        invalid_values = df1[pd.to_numeric(df1[col], errors='coerce') <= 0]
        
        if len(comma_values) > 0:
            print(f"❌ {col}: Found {len(comma_values)} values with COMMA separator")
            print(f"   Sample: {comma_values[col].head(3).tolist()}")
        else:
            print(f"✓ {col}: All values use dot (.) or are numeric")
        if len(invalid_values) > 0:
            print(f"❌ {col}: Found {len(invalid_values)} values that are <= 0")
            print(f"   Sample: {invalid_values[col].head(3).tolist()}")
        else:
            print(f"✓ {col}: All values are greater than 0")
    else:
        print(f"⚠ {col}: Column not found in data")
    print()
# Out:
# Checking price field separators (should use dot '.' not comma ','):
#
# ✓ store_id: All values use dot (.) or are numeric
# ✓ store_id: All values are greater than 0
#
# ✓ pin_code: All values use dot (.) or are numeric
# ✓ pin_code: All values are greater than 0
#
# ✓ unique_id: All values use dot (.) or are numeric
# ✓ unique_id: All values are greater than 0
#
# ✓ product_grammage: All values use dot (.) or are numeric
# ✓ product_grammage: All values are greater than 0
#
# ✓ net_quantity: All values use dot (.) or are numeric
# ✓ net_quantity: All values are greater than 0
#
# ✓ item_mrp: All values use dot (.) or are numeric
# ✓ item_mrp: All values are greater than 0
#
# ✓ item_selling_price: All values use dot (.) or are numeric
# ✓ item_selling_price: All values are greater than 0
#
# ✓ product_price: All values use dot (.) or are numeric
# ✓ product_price: All values are greater than 0
#
# ✓ promo_offer_price: All values use dot (.) or are numeric
# ✓ promo_offer_price: All values are greater than 0
#
# ✓ discount_in_percent: All values use dot (.) or are numeric
# ❌ discount_in_percent: Found 244453 values that are <= 0
#    Sample: [0, 0, 0]
#
# ✓ stock_count: All values use dot (.) or are numeric
# ❌ stock_count: Found 423226 values that are <= 0
#    Sample: [0, 0, 0]

# %%
# Check for numeric columns that should not have negative values or zero

numeric_columns = ['store_id','pin_code','unique_id','product_grammage','net_quantity', 'item_mrp','item_selling_price', 'product_price','promo_offer_price','discount_in_percent','stock_count']

print("Checking price field separators (should use dot '.' not comma ','):\n")

for col in numeric_columns:
    if col in df2.columns:
        # Find rows with comma in price field
        comma_values = df2[df2[col].astype(str).str.contains(',', na=False)]
        invalid_values = df2[pd.to_numeric(df2[col], errors='coerce') <= 0]
        
        if len(comma_values) > 0:
            print(f"❌ {col}: Found {len(comma_values)} values with COMMA separator")
            print(f"   Sample: {comma_values[col].head(3).tolist()}")
        else:
            print(f"✓ {col}: All values use dot (.) or are numeric")
        if len(invalid_values) > 0:
            print(f"❌ {col}: Found {len(invalid_values)} values that are <= 0")
            print(f"   Sample: {invalid_values[col].head(3).tolist()}")
        else:
            print(f"✓ {col}: All values are greater than 0")
    else:
        print(f"⚠ {col}: Column not found in data")
    print()
# Out:
# Checking price field separators (should use dot '.' not comma ','):
#
# ✓ store_id: All values use dot (.) or are numeric
# ✓ store_id: All values are greater than 0
#
# ✓ pin_code: All values use dot (.) or are numeric
# ✓ pin_code: All values are greater than 0
#
# ✓ unique_id: All values use dot (.) or are numeric
# ✓ unique_id: All values are greater than 0
#
# ✓ product_grammage: All values use dot (.) or are numeric
# ✓ product_grammage: All values are greater than 0
#
# ✓ net_quantity: All values use dot (.) or are numeric
# ✓ net_quantity: All values are greater than 0
#
# ✓ item_mrp: All values use dot (.) or are numeric
# ❌ item_mrp: Found 2 values that are <= 0
#    Sample: [0, 0]
#
# ✓ item_selling_price: All values use dot (.) or are numeric
# ❌ item_selling_price: Found 2 values that are <= 0
#    Sample: [0, 0]
#
# ✓ product_price: All values use dot (.) or are numeric
# ❌ product_price: Found 2 values that are <= 0
#    Sample: [0, 0]
#
# ✓ promo_offer_price: All values use dot (.) or are numeric
# ❌ promo_offer_price: Found 2 values that are <= 0
#    Sample: [0, 0]
#
# ✓ discount_in_percent: All values use dot (.) or are numeric
# ❌ discount_in_percent: Found 286259 values that are <= 0
#    Sample: [0, 0, 0]
#
# ✓ stock_count: All values use dot (.) or are numeric
# ❌ stock_count: Found 441477 values that are <= 0
#    Sample: [0, 0, 0]

# %%
# check for stock_count and out_of_stock_flag consistency
# Convert stock_count to numeric if needed
df2['stock_count'] = pd.to_numeric(
    df2['stock_count'], errors='coerce'
)

# Find rows violating the rule
invalid_rows = df2[
    # (
    #     (df2['stock_count'] == 0) &
    #     (df2['out_of_stock_flag'].str.strip().str.lower() != 'yes')
    # )
    # |
    (
        (df2['stock_count'] > 0) &
        (df2['out_of_stock_flag'].str.strip().str.lower() != 'no')
    )
]

print(f"Number of violating rows: {len(invalid_rows)}")
print(invalid_rows)
# Out:
# Number of violating rows: 0
# Empty DataFrame
# Columns: [crawl_date_and_time, platform_name, store_id, store_name_location, city, pin_code, unique_id, product_id_upc_ean, department, category, sub_category, product_type, brand_name, product_name, product_description, product_grammage, package_type, net_quantity, variants, item_mrp, item_selling_price, out_of_stock_flag, discount_flag, product_price, unit_price, promo_offer_description, promo_offer_price, discount_in_percent, stock_count, product_url, product_image_urls]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# ***Insights :***
# ____________
#
#     * Suspicious values noticed on brand_name column.
#     * Checked website to confirm whether these brand_names really exists or not.
#     * Most of them really exists, but urls of some brands are not able to access.
#     * Complete urls on brand_name 'RG' and 'C4' and some urls on other brands are not accessible, which is a critical issue.

# %% [markdown]
# **10) Price Anomalies**

# %%
def check_negative_and_zero(df, column):
    """
    Returns rows where the given column has:
    - negative values (< 0)
    - zero values (== 0)
    """

    # Ensure numeric (safe for real-world messy data)
    df2[column] = pd.to_numeric(df2[column], errors='coerce')

    negative_values = df2[df2[column] < 0]
    zero_values = df2[df2[column] == 0]

    return {
        "negative_values": negative_values[['unique_id', column]],
        "zero_values": zero_values[['unique_id', column]]
    }

print("\nItem MRP:")
print(check_negative_and_zero(df2, 'item_mrp'))
print("\nItem Selling Price:")
print(check_negative_and_zero(df2, 'item_selling_price'))
print("\nProduct Price:")
print(check_negative_and_zero(df2, 'product_price'))
print("\nPromo Offer Price:")
print(check_negative_and_zero(df2, 'promo_offer_price'))
# Out:
# Item MRP:
# {'negative_values': Empty DataFrame
# Columns: [unique_id, item_mrp]
# Index: [], 'zero_values': Empty DataFrame
# Columns: [unique_id, item_mrp]
# Index: []}
#
# Item Selling Price:
# {'negative_values': Empty DataFrame
# Columns: [unique_id, item_selling_price]
# Index: [], 'zero_values': Empty DataFrame
# Columns: [unique_id, item_selling_price]
# Index: []}
#
# Product Price:
# {'negative_values': Empty DataFrame
# Columns: [unique_id, product_price]
# Index: [], 'zero_values': Empty DataFrame
# Columns: [unique_id, product_price]
# Index: []}
#
# Promo Offer Price:
# {'negative_values': Empty DataFrame
# Columns: [unique_id, promo_offer_price]
# Index: [], 'zero_values': Empty DataFrame
# Columns: [unique_id, promo_offer_price]
# Index: []}

# %%
# check if item_selling_price is greater than item_mrp
df2[df2['item_selling_price'] > df2['item_mrp']][['unique_id', 'item_selling_price', 'item_mrp']]
# Out:
# Empty DataFrame
# Columns: [unique_id, item_selling_price, item_mrp]
# Index: []

# %%
# check if discount_in_percent is greater than 0 and item_selling_price is greater than or equal to item_mrp
df2[
    (df2['discount_in_percent'] > 0) &
    (df2['item_selling_price'] >= df2['item_mrp'])
][['unique_id', 'item_selling_price', 'item_mrp', 'discount_in_percent']]
# Out:
# Empty DataFrame
# Columns: [unique_id, item_selling_price, item_mrp, discount_in_percent]
# Index: []

# %%
# check if promo_offer_description is not null and promo_offer_price is null
df2[
    (df2['promo_offer_description'].notnull()) &

    (df2['promo_offer_price'].isnull())][['unique_id', 'promo_offer_description', 'promo_offer_price']]
# Out:
# Empty DataFrame
# Columns: [unique_id, promo_offer_description, promo_offer_price]
# Index: []

# %%
# check if promo_offer_price is not null and promo_offer_price is not equal to item_selling_price
df2[
    (df2['promo_offer_price'].notnull()) &
    (df2['promo_offer_price'] != df2['item_selling_price'])
][['unique_id', 'promo_offer_description', 'promo_offer_price', 'item_selling_price']]
# Out:
# Empty DataFrame
# Columns: [unique_id, promo_offer_description, promo_offer_price, item_selling_price]
# Index: []

# %%
# check if out_of_stock_flag is True and stock_count is greater than 0
df2[
    (df2['out_of_stock_flag'] == True) &
    (df2['stock_count'] > 0)
][['unique_id', 'store_id', 'product_id_upc_ean']]
# Out:
# Empty DataFrame
# Columns: [unique_id, store_id, product_id_upc_ean]
# Index: []

# %% [markdown]
# ***Insights :***
# ____________
#
#     * No specific anomalies found on price related columns
#     * All such columns are greater than 0.
#     * selling price and mrp are equal.
#     * selling price is always less than mrp if discount percentage exists.
#     * if promo offer description exists, promo offer price also exists.
#     * If out of stock flag true, stock count is zero.

# %% [markdown]
# **11) URL Checking**

# %%
total_records = len(df2)
missing_urls = df2['product_url'].isnull().sum()
unique_urls = df2['product_url'].nunique(dropna=True)
duplicate_urls = df2['product_url'].duplicated().sum()

print("URL ANALYSIS SUMMARY")
print("-" * 40)
print(f"Total records           : {total_records}")
print(f"Missing URLs            : {missing_urls}")
print(f"Unique URLs             : {unique_urls}")
print(f"Duplicate URLs          : {duplicate_urls}")
print(f"Uniqueness %            : {(unique_urls/total_records)*100:.2f}%")
# Out:
# URL ANALYSIS SUMMARY
# ----------------------------------------
# Total records           : 1177307
# Missing URLs            : 0
# Unique URLs             : 23419
# Duplicate URLs          : 1153888
# Uniqueness %            : 1.99%

# %%
# Duplicate URL Records
# ----------------------------
duplicate_url_df = df2[
    df2['product_url'].duplicated(keep=False)
].sort_values('product_url')

print("\nDuplicate URL Records:")
print(duplicate_url_df[['unique_id', 'product_name', 'product_url']].head())
# Out:
# Duplicate URL Records:
#          unique_id  \
# 248806  DM3JP3ZJ8T
# 540313  UIQ46NIA5D
# 528268  AVZ8DI1TJC
# 959888  TBNV2ZPLOF
# 968875  X7IUIPMO9X
#
#                                                                                   product_name  \
# 248806  FACES CANADA Ultime Pro Splash Nail Enamel - Pink Rouge 103 (8ml)Glossy | Quick Drying
# 540313  FACES CANADA Ultime Pro Splash Nail Enamel - Pink Rouge 103 (8ml)Glossy | Quick Drying
# 528268  FACES CANADA Ultime Pro Splash Nail Enamel - Pink Rouge 103 (8ml)Glossy | Quick Drying
# 959888  FACES CANADA Ultime Pro Splash Nail Enamel - Pink Rouge 103 (8ml)Glossy | Quick Drying
# 968875  FACES CANADA Ultime Pro Splash Nail Enamel - Pink Rouge 103 (8ml)Glossy | Quick Drying
#
#                                              product_url
# 248806  https://www.swiggy.com/instamart/item/0009OYBIMZ
# 540313  https://www.swiggy.com/instamart/item/0009OYBIMZ
# 528268  https://www.swiggy.com/instamart/item/0009OYBIMZ
# 959888  https://www.swiggy.com/instamart/item/0009OYBIMZ
# 968875  https://www.swiggy.com/instamart/item/0009OYBIMZ

# %%
# ----------------------------
# URL Format Validation
# ----------------------------

# Regex for HTTP/HTTPS URLs
url_pattern = re.compile(
    r'^(https?://)'               # http:// or https://
    r'([\w.-]+)'                  # domain
    r'(\.[a-zA-Z]{2,})'           # TLD
    r'([/\w .?%&=+-]*)?$'         # path/query
)

invalid_urls = df2[
    df2['product_url'].notnull() &
    ~df2['product_url'].astype(str).str.match(url_pattern)
]

print("\nInvalid URL Format Count:", len(invalid_urls))

print("\nSample Invalid URLs:")
print(
    invalid_urls[
        ['unique_id', 'product_name', 'product_url']
    ].head(10)
)
# Out:
# Invalid URL Format Count: 0
#
# Sample Invalid URLs:
# Empty DataFrame
# Columns: [unique_id, product_name, product_url]
# Index: []

# %%
# ----------------------------
# URLs without http/https
# ----------------------------
missing_protocol = df2[
    df2['product_url'].notnull() &
    ~df2['product_url'].astype(str).str.startswith(('http://', 'https://'))
]

print("\nURLs missing protocol (http/https):", len(missing_protocol))

print(
    missing_protocol[
        ['unique_id', 'product_name', 'product_url']
    ].head()
)
# Out:
# URLs missing protocol (http/https): 0
# Empty DataFrame
# Columns: [unique_id, product_name, product_url]
# Index: []

# %% [markdown]
# ***Insights***
# ___________
# * Format and pattern of urls are correct
# * But 1210545 duplicate urls present on the dataset.
# * However these duplcates have different store location and different price range.

# %% [markdown]
# **12) City, Store, Pincode Analysis**

# %%
# Missing percentage by city

missing_by_city = (
    df2.groupby('city')
      .apply(lambda x: x.isnull().mean().mean() * 100)
      .reset_index(name='missing_perc')
      .sort_values('missing_perc', ascending=False)
)

# Stockout percentage by city

df2['out_of_stock_flag_num'] = (
    df2['out_of_stock_flag']
    .astype(str)
    .str.lower()
    .isin(['true', 'yes', '1', 'y'])
    .astype(int)
)

stockout_by_city = (
    df2.groupby('city')['out_of_stock_flag_num']
      .mean()
      .mul(100)
      .reset_index(name='stockout_perc')
      .sort_values('stockout_perc', ascending=False)
)

# Discount percentage by city

discount_by_city = (
    df2.groupby('city')['discount_in_percent']
      .mean()
      .reset_index(name='avg_discount_perc')
      .sort_values('avg_discount_perc', ascending=False)
) 

# Number of unique products by city

products_by_city = (
    df2.groupby('city')['unique_id']
      .nunique()
      .reset_index(name='product_count')
      .sort_values('product_count', ascending=False)
)

# Combine all metrics
city_analysis = (
    missing_by_city
    .merge(stockout_by_city, on='city', how='outer')
    .merge(discount_by_city, on='city', how='outer')
    .merge(products_by_city, on='city', how='outer')
    .sort_values('missing_perc', ascending=False)
)

print("\nCITY ANALYSIS SUMMARY")
print("--------------------------------")
print(city_analysis)
# Out:
# /tmp/ipykernel_7817/382486877.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.isnull().mean().mean() * 100)
# CITY ANALYSIS SUMMARY
# --------------------------------
#       city  missing_perc  stockout_perc  avg_discount_perc  product_count
# 1  Gurgaon     16.129612      34.156646          15.671629         298016
# 0    Delhi     16.129546      39.014655          14.767723         656122

# %%
# Missing percentage by store

missing_by_store = (
    df2.groupby('store_name_location')
      .apply(lambda x: x.isnull().mean().mean() * 100)
      .reset_index(name='missing_perc')
      .sort_values('missing_perc', ascending=False)
)

# Stockout percentage by store

df2['out_of_stock_flag_num'] = (
    df2['out_of_stock_flag']
    .astype(str)
    .str.lower()
    .isin(['true', 'yes', '1', 'y'])
    .astype(int)
)

stockout_by_store = (
    df2.groupby('store_name_location')['out_of_stock_flag_num']
      .mean()
      .mul(100)
      .reset_index(name='stockout_perc')
      .sort_values('stockout_perc', ascending=False)
)

# Discount percentage by store

discount_by_store = (
    df2.groupby('store_name_location')['discount_in_percent']
      .mean()
      .reset_index(name='avg_discount_perc')
      .sort_values('avg_discount_perc', ascending=False)
) 

# Number of unique products by store

products_by_store = (
    df2.groupby('store_name_location')['unique_id']
      .nunique()
      .reset_index(name='product_count')
      .sort_values('product_count', ascending=False)
)

# Combine all metrics
store_analysis = (
    missing_by_store
    .merge(stockout_by_store, on='store_name_location', how='outer')
    .merge(discount_by_store, on='store_name_location', how='outer')
    .merge(products_by_store, on='store_name_location', how='outer')
    .sort_values('missing_perc', ascending=False)
)

print("\nSTORE ANALYSIS SUMMARY")
print("--------------------------------")
print(store_analysis)
# Out:
# /tmp/ipykernel_7817/2116988899.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.isnull().mean().mean() * 100)
# STORE ANALYSIS SUMMARY
# --------------------------------
#                                                                                                   store_name_location  \
# 47                                                         Gupta Traders, Vikaspuri, West Delhi, Delhi, 110018, India
# 29                            B-304, Gharoli Rd, GD Colony, Phase 3, Gharoli Dairy Farm, Kondli, Delhi, 110096, India
# 89  Sweet Little Things, 1/47, Azad Hind Fauj Marg, Block A, Sewak Park, Uttam Nagar, New Delhi, Delhi, 110059, India
# 18                                                           A-24, Chander Nagar, Krishna Nagar, Delhi, 110051, India
# 38                        DTDC Ashram Branch, Friends Colony West, New Friends Colony, New Delhi, Delhi 110065, India
# ..                                                                                                                ...
# 69               Parking Area, Jwalaheri Market, Rd Number 30, Jwalaheri Village, Paschim Vihar, Delhi, 110063, India
# 15                           50, 55 Foota Road, Vipin Garden Extension, Kamerdin Nagar, Nangloi, Delhi, 110059, India
# 9                        2, Jaitpur Rd, Near Central Bank, Hari Nagar Extn, Badarpur, New Delhi, Delhi, 110044, India
# 8                                                 199, Gujranwala Town Part, 2, Gujranwala Town, Delhi, 110009, India
# 57                    Kamal Garden, Shop No 1, Division, Pocket 9, Sector 11, Rohini, New Delhi, Delhi, 110086, India
#
#     missing_perc  stockout_perc  avg_discount_perc  product_count
# 47     15.626132      38.882348          14.342541           9042
# 29     15.626093      43.603499          14.986822           6905
# 89     15.626047      49.519982          14.303639           7189
# 18     15.626046      41.786551          14.237203           7214
# 38     15.626044      43.919822          14.300111           7216
# ..           ...            ...                ...            ...
# 69     15.625000      27.083855          15.613684           9455
# 15     15.625000      24.174449          15.796284           8165
# 9      15.625000      36.817883          15.666174           9886
# 8      15.625000      48.759983          14.729508           7617
# 57     15.625000      18.211734          15.250846           8459
#
# [98 rows x 5 columns]

# %%
# Missing percentage by pincode

missing_by_pincode = (
    df2.groupby('pin_code')
      .apply(lambda x: x.isnull().mean().mean() * 100)
      .reset_index(name='missing_perc')
      .sort_values('missing_perc', ascending=False)
)

# Stockout percentage by pincode

df2['out_of_stock_flag_num'] = (
    df2['out_of_stock_flag']
    .astype(str)
    .str.lower()
    .isin(['true', 'yes', '1', 'y'])
    .astype(int)
)

stockout_by_pincode = (
    df2.groupby('pin_code')['out_of_stock_flag_num']
      .mean()
      .mul(100)
      .reset_index(name='stockout_perc')
      .sort_values('stockout_perc', ascending=False)
)

# Discount percentage by pincode

discount_by_pincode = (
    df2.groupby('pin_code')['discount_in_percent']
      .mean()
      .reset_index(name='avg_discount_perc')
      .sort_values('avg_discount_perc', ascending=False)
) 

# Number of unique products by pincode

products_by_pincode = (
    df2.groupby('pin_code')['unique_id']
      .nunique()
      .reset_index(name='product_count')
      .sort_values('product_count', ascending=False)
)

# Combine all metrics
pincode_analysis = (
    missing_by_pincode
    .merge(stockout_by_pincode, on='pin_code', how='outer')
    .merge(discount_by_pincode, on='pin_code', how='outer')
    .merge(products_by_pincode, on='pin_code', how='outer')
    .sort_values('missing_perc', ascending=False)
)

print("\nPINCODE ANALYSIS SUMMARY")
print("--------------------------------")
print(pincode_analysis)
# Out:
# /tmp/ipykernel_7817/1523724332.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.isnull().mean().mean() * 100)
# PINCODE ANALYSIS SUMMARY
# --------------------------------
#     pin_code  missing_perc  stockout_perc  avg_discount_perc  product_count
# 43    110096     15.626093      43.603499          14.986822           6905
# 3     110008     15.625891      41.852732          14.598480           8639
# 53    122052     15.625870      24.796437          15.713620          11909
# 39    110092     15.625800      46.402252          14.453071          15908
# 7     110018     15.625778      42.670523          14.519455          26003
# 28    110065     15.625747      44.605717          14.489532          23595
# 15    110037     15.625741      30.535679          15.052461          20753
# 55    122505     15.625731      28.090413          16.066173          10333
# 50    122017     15.625720      40.061761          15.624732          35324
# 42    110095     15.625688      46.646476          14.319879          14661
# 14    110032     15.625688      48.289141          14.345913           7341
# 34    110085     15.625684      40.649499          14.590987          36802
# 17    110042     15.625657      40.477192          14.913181           7642
# 51    122018     15.625653      35.211436          15.661404          27278
# 9     110022     15.625635      47.381255          14.337211          15801
# 24    110051     15.625633      43.347857          14.499189          15906
# 44    122001     15.625619      37.842924          15.576369          40975
# 36    110087     15.625605      26.758928          15.123681           8310
# 48    122009     15.625605      36.539578          15.683995          21041
# 10    110024     15.625600      42.828360          14.527679          16800
# 47    122005     15.625596      31.864614          15.499657          21491
# 30    110074     15.625589      35.738983          15.026718          13115
# 0     110005     15.625578      49.435969          14.379103          17739
# 6     110017     15.625577      46.449499          14.541042          17435
# 54    122102     15.625572      29.625951          15.796743          31169
# 13    110028     15.625567      31.003205          15.139082          13754
# 18    110043     15.625538      35.907801          14.902210           9455
# 12    110027     15.625534      43.722919          14.302395          14084
# 1     110006     15.625532      57.270560          14.754555           9517
# 29    110070     15.625528      40.982082          14.560091           9543
# 8     110019     15.625500      37.879678          14.795281          15082
# 23    110049     15.625499      51.901971          14.874694          15774
# 2     110007     15.625497      29.314872          15.099706          10581
# 38    110091     15.625495      38.988284          14.665690          20582
# 33    110084     15.625477      34.471979          14.662219          10475
# 37    110088     15.625474      43.796727          14.628410          16037
# 45    122003     15.625446      33.509955          15.618783          46094
# 31    110075     15.625442      37.906048          14.812485          23575
# 26    110059     15.625429      36.010586          14.877142          40875
# 5     110015     15.625428      33.264868          14.459492          17640
# 20    110045     15.625357      38.415563          14.787993          21480
# 52    122022     15.625357      34.723544          15.662354          21327
# 49    122011     15.625335      33.958281          15.891338          22776
# 11    110025     15.625265      25.525959          15.344248           9354
# 46    122004     15.625257      28.674957          15.506300           9642
# 25    110052     15.625256      32.860539          14.485775           9750
# 22    110047     15.625251      27.616980          15.708956           9940
# 16    110041     15.625241      33.544548          15.186693          10409
# 21    110046     15.625234      33.395788          14.639361          10710
# 41    110094     15.625221      26.961373          14.986371          11439
# 32    110080     15.625169      40.192943          15.136741          15466
# 40    110093     15.625166      36.212129          14.988180          15802
# 19    110044     15.625000      36.817883          15.666174           9886
# 27    110063     15.625000      29.010842          15.334575          16653
# 35    110086     15.625000      18.211734          15.250846           8459
# 4     110009     15.625000      48.759983          14.729508           7617

# %% [markdown]
# ***Insights :***
# __________________
#
#     * missing percentage is almost equally distributed over all dimensions
#     * stockout percentage and product count has significant hike based on some cities, stores, pincodes etc.
#     * However discount_percentage is also have almost equal distribution over different dimensions

# %% [markdown]
# **13) High Price Variations**

# %%
# Price Variation Analysis
price_variation = (
    df2.groupby('product_id_upc_ean')
      .agg(
          product_name=('product_name', 'first'),
          min_price=('item_selling_price', 'min'),
          max_price=('item_selling_price', 'max'),
          mean_price=('item_selling_price', 'mean'),
          num_locations=('city', 'nunique')
      )
      .reset_index()
)

# Calculate percentage variation
price_variation['price_variation_pct'] = (
    (price_variation['max_price'] - price_variation['min_price'])
    / price_variation['min_price'] * 100
).round(2)

# Flag products having >30% variation
high_variation = price_variation[
    price_variation['price_variation_pct'] > 30
].sort_values('price_variation_pct', ascending=False)

print(high_variation.head(20))
# Out:
#       product_id_upc_ean  \
# 20651         VNHYEZVXHA
# 1264          1UTQYINACZ
# 6828          A6LG9EVLAP
# 21539         X1UP6TZ2CH
# 4106          63FRSPU0EC
# 9856          ESWAQTN109
# 11289         GY12SME90J
# 8590          CWA1JGHGHP
# 14751         M9QXZYJMLV
# 16940         PKGH8JLDJ3
# 11381         H3O2WU1A10
# 16852         PFG8AJNMYI
# 21349         WR36KX1BPP
# 4800          72LBIS8S50
# 22123         XZEKYCTJGF
# 2034          30EEACLT1J
# 21193         WIHUB87TYB
# 12580         IWYG3OXTEA
# 7010          AHDYQM8J94
# 3247          4SUMRVSQ0K
#
#                                                                                               product_name  \
# 20651                                                 Tommy Hilfiger Impact Spark Penspray Eau de Toilette
# 1264                                                         The Health Factory Berry Blast Mini Cakes 70g
# 6828   Open Secret Zero Maida Chocolate Biscuit Cookies,Healthy Snacks with No Refined Sugar & No Palm Oil
# 21539                                                     CLEAR Premium Drinking Water with Added Minerals
# 4106                                                        NOICE Natural Coconut Water (No Preservatives)
# 9856                                                                Himalayan Natural Mineral Water Bottle
# 11289                                             NOICE Coconut Water With Malai Chunks (No Preservatives)
# 8590                                                        Red Bull The Yellow Edition Energy Drink 250ml
# 14751                                               Red Bull Energy Drink Watermelon The Red Edition 250ml
# 16940                                                               Red Bull Sugar Free Energy Drink 250ml
# 11381                                                                                     POLO Breath Mint
# 16852                                        NOICE Chocolate Almond Shots (Made From Couverture Chocolate)
# 21349                                                                                    Milky Mist Paneer
# 4800            SOFTSENS Kids Teddy Bear Soap|Hypoallergenic|Dermatologist Tested|Shea Butter & Milk Cream
# 22123                                            The Baker's Dozen Banana Muffin Zero Maida, Zero Palm Oil
# 2034                                                           Himalayan Natural Mineral Water With pH 7-8
# 21193                                                                             Maaza Mango Drink Bottle
# 12580                                                   Peping Digestive Shot Orange|Spearmint| Probiotics
# 7010                                                                            Bisleri Mineral Water 1ltr
# 3247                                                                            Heritage Lite Fit Uht Milk
#
#        min_price  max_price  mean_price  num_locations  price_variation_pct
# 20651          0        975  942.500000              2                  inf
# 1264          50       5017  130.979798              2              9934.00
# 6828          29       2571   55.341969              2              8765.52
# 21539          5        305   34.620000              2              6000.00
# 4106          29        936  176.005000              2              3127.59
# 9856          18        480  403.466667              2              2566.67
# 11289         45       1080  291.030151              2              2300.00
# 8590         125       2799  756.868687              2              2139.20
# 14751        125       2700  771.313131              2              2060.00
# 16940        125       2640  646.400000              2              2012.00
# 11381         10        200   28.140704              2              1900.00
# 16852         10        198   91.319797              2              1880.00
# 21349         35        602  521.126437              2              1620.00
# 4800          64       1093  143.153846              2              1607.81
# 22123         10        160   76.267123              2              1500.00
# 2034          44        701  277.010000              2              1493.18
# 21193         60        900   92.500000              2              1400.00
# 12580         30        450  153.000000              2              1400.00
# 7010          18        240   73.380000              2              1233.33
# 3247          66        864  197.220000              2              1209.09

# %%
# check if any product has more than one selling price with same grammage across different stores
price_variation = (
    df2.groupby(['product_name', 'product_grammage'])['item_selling_price']
      .nunique()
      .reset_index(name='price_count')
)

# Keep only products having more than one selling price
price_variation = price_variation[
    price_variation['price_count'] > 1
]

print(price_variation)
# Out:
#                                                                           product_name  \
# 2                                                                    10X Classic Besan
# 3                                                                    10X Classic Besan
# 4                                                        10X Classic Chakki Fresh Atta
# 5                                                        10X Classic Chakki Fresh Atta
# 6                                                                    10X Classic Dalia
# ...                                                                                ...
# 28464   plum bodylovin shower gel - hawaiian rumba and deodorant roll-on and body mist
# 28465                               plum coconut milk & peptides shampoo & conditioner
# 28466  plum coconut milk & peptides strength & shine shampoo, conditioner & hair serum
# 28467                        plum green tea alcohol free toner and cleansing face wash
# 28468         plum green tea oil free moisturiser and free toner & cleansing face wash
#
#       product_grammage  price_count
# 2                 1 kg            2
# 3                500 g            2
# 4                10 kg            3
# 5                 5 kg            2
# 6                500 g            2
# ...                ...          ...
# 28464          1 combo            2
# 28465          1 combo            3
# 28466          1 combo            3
# 28467          1 combo            3
# 28468          1 combo            3
#
# [9501 rows x 3 columns]

# %%
# Group by product_name and product_grammage and find price varation statistics
price_analysis = (
    df2.groupby(['product_name', 'product_grammage'])['item_selling_price']
      .agg(['count', 'min', 'max', 'mean', 'std'])
      .reset_index()
)

# Calculate price difference and percentage variation
price_analysis['price_diff'] = (
    price_analysis['max'] - price_analysis['min']
)

price_analysis['pct_variation'] = (
    (price_analysis['price_diff'] / price_analysis['mean']) * 100
).round(2)

# Flag products with >20% variation
high_variation = price_analysis[
    price_analysis['pct_variation'] > 20
].sort_values('pct_variation', ascending=False)

print(high_variation)
# Out:
#                                                                                                                                                     product_name  \
# 18724                                                        Open Secret Zero Maida Chocolate Biscuit Cookies,Healthy Snacks with No Refined Sugar & No Palm Oil
# 25666                                                                                                                  The Health Factory Berry Blast Mini Cakes
# 8681                                                                                                                                     Frubon Premium Dahi Cup
# 21105                                                                                                   RAS Luxory Skincare Kashmiri Lavender Pure Essential Oil
# 10992                                                                                                              Imli Blast - Sweet Chilli Fruit Bars Fun Pack
# ...                                                                                                                                                          ...
# 19753              Patanjali Nutrela Collagen Prash Supplement for Glowing & Younger Looking Skin - | Patanjali Collagen Builder Skin Super Food for Men & Women
# 15522                                            MeeMee Musical Cot Assorted Mobile Hanger - Nursery Decoration, Baby Shower, Soothing Music, Best for 0-2 Years
# 2664   BeeBaby Ease Wide Neck Colour Baby Feeding Bottle. Fast Flow Anti-Colic Silicone Nipple for infants, and newborns. 100% BPA Free. 4 months+ (150ml, Blue)
# 27965                                                         Yoga Bar 26% High Protein Oats, Fruits, Nuts & Seeds, No Added Sugar, High Fibre, Added Probiotics
# 18203                                                                                                 Nua 360° Comfort Disposable Period Panties (S-M, 5 Pieces)
#
#       product_grammage  count   min    max         mean          std  \
# 18724             40 g    193    29   2571    55.341969   258.094030
# 25666             70 g     59    50   5017   134.186441   646.648321
# 8681             400 g     53    47    545    56.396226    68.405561
# 21105            10 ml    244  1100  11000  1221.819672  1093.206151
# 10992             42 g     92    30    288    32.804348    26.898359
# ...                ...    ...   ...    ...          ...          ...
# 19753            400 g     12   557    680   614.000000    61.361818
# 15522           1 Pack     35   800    999   993.314286    33.637139
# 2664           1 Piece      6   129    160   154.833333    12.655697
# 27965             1 kg    100   339    407   339.680000     6.800000
# 18203         5 pieces     83   179    215   179.867470     5.554104
#
#        price_diff  pct_variation
# 18724        2542        4593.26
# 25666        4967        3701.57
# 8681          498         883.04
# 21105        9900         810.27
# 10992         258         786.48
# ...           ...            ...
# 19753         123          20.03
# 15522         199          20.03
# 2664           31          20.02
# 27965          68          20.02
# 18203          36          20.01
#
# [2131 rows x 9 columns]

# %%
# check if any product has more than one selling price with same grammage on same store
price_variation = (
    df2.groupby(['store_id', 'product_name', 'product_grammage'])['item_selling_price']
      .agg(['min', 'max', 'nunique', 'count'])
      .reset_index()
)

# Keep only products having more than one unique selling price
price_variation = price_variation[
    price_variation['nunique'] > 1
]

# Calculate price difference
price_variation['price_difference'] = (
    price_variation['max'] - price_variation['min']
)

print(price_variation.sort_values('price_difference', ascending=False))
# Out:
#         store_id  \
# 820423   1404576
# 316941   1388689
# 127231   1267917
# 759029   1403207
# 612184   1402056
# ...          ...
# 90446    1099459
# 626827   1402248
# 685241   1402608
# 73793    1099457
# 72585    1099457
#
#                                                                                                product_name  \
# 820423                                              Fabelle Ganache Creamy Milk, Luxury Chocolates Gift Box
# 316941                          Matrix Mega Smooth Anti-Frizz Combo with Shea butter - 4-Days Frizz Control
# 127231                          Matrix Mega Smooth Anti-Frizz Combo with Shea butter - 4-Days Frizz Control
# 759029                          Matrix Mega Smooth Anti-Frizz Combo with Shea butter - 4-Days Frizz Control
# 612184                                                                      Lindt Lindor Assorted Chocolate
# ...                                                                                                     ...
# 90446                                                                        Small Tender Coconut (Nariyal)
# 626827                                                                                   Rajdhani Chana Dal
# 685241                                                              NOICE Fresh Sponge Cake (Zero Palm oil)
# 73793        Neutrogena Oil Free Acne Face Wash With 2.0% Salicylic Acid For Effective Yet Gentle Cleansing
# 72585   Let's Try Pratham hing Jeera Channa No palm oil & Let's try peanut party mix, made in groundnut oil
#
#        product_grammage  min   max  nunique  count  price_difference
# 820423            124 g  470  1099        2      2               629
# 316941          1 combo  631  1193        2      4               562
# 127231          1 combo  631  1193        2      4               562
# 759029          1 combo  663  1215        2      4               552
# 612184            200 g  255   802        2      3               547
# ...                 ...  ...   ...      ...    ...               ...
# 90446          1 Pieces   82    84        2      2                 2
# 626827             1 kg  119   121        2      2                 2
# 685241             90 g   49    51        2      2                 2
# 73793            175 ml  734   735        2      2                 1
# 72585           1 Combo  190   191        2      2                 1
#
# [749 rows x 8 columns]

# %% [markdown]
# ***Insights :***
# _________________
#
#     * Found price anomalies with high variation of price for the same product with the same grammage unit.
#     * Multiple products are there with the same product_name, grammage, store_name, and different offer price.
#     * The product_url of such products are too same and not accessible.

# %%
categories1 = set(df1['category'].dropna().unique())
categories2 = set(df2['category'].dropna().unique())

print("Categories only in df1:")
print(sorted(categories1 - categories2))

print("\nCategories only in df2:")
print(sorted(categories2 - categories1))

print("\nCommon categories:")
print(sorted(categories1 & categories2))

print("\nAre the category values identical?")
print(categories1 == categories2)
# Out:
# Categories only in df1:
# []
#
# Categories only in df2:
# []
#
# Common categories:
# ['Atta, Rice and Dal', 'Baby Care', 'Bath and Body', 'Biscuits and Cakes', 'Cereals and Breakfast', 'Chips and Namkeens', 'Chocolates', 'Cold Drinks and Juices', 'Dairy, Bread and Eggs', 'Feminine Hygiene', 'Hair Care', 'Ice Creams and Frozen Desserts', 'Makeup', 'Paan Corner', 'Skincare', 'Sweet Corner']
#
# Are the category values identical?
# True

# %%
subcategories1 = set(df1['sub_category'].dropna().unique())
subcategories2 = set(df2['sub_category'].dropna().unique())

print("Subcategories only in df1:")
print(sorted(subcategories1 - subcategories2))

print("\nSubcategories only in df2:")
print(sorted(subcategories2 - subcategories1))

print("\nCommon subcategories:")
print(sorted(subcategories1 & subcategories2))

print("\nAre the subcategory values identical?")
print(subcategories1 == subcategories2)
# Out:
# Subcategories only in df1:
# ['Fresh Bakery']
#
# Subcategories only in df2:
# []
#
# Common subcategories:
# ['Atta', 'Baby Bathing', 'Baby Cream & Lotions', 'Baby Diapers', 'Baby Food and Formula', 'Baby Hygiene', 'Baby Oil and Talc', 'Baby Oral Care', 'Baby Pharma', 'Baby Wipes', 'Baking Ingredients', 'Bath & Beauty gifts', 'Bath Accessories', 'Batters', 'Beauty Supplements', 'Besan, Sooji and Maida', 'Bhujia and Namkeens', 'Body Lotion & Oils', 'Body Lotions', 'Books and Toys', 'Bread and Buns', 'Butter', 'Cakes & Pies', 'Cakes & Sandwiches', 'Cakes and Pies', 'Candies & More', 'Cheese', 'Chikki', 'Chips and Crisps', 'Chocofills', 'Clothes & Accessories', 'Coconut Water', 'Cold Coffee', 'Combs & Brushes', 'Conditioners & Masks', 'Cones', 'Cookies', 'Cream Biscuits', 'Cream and Condensed Milk', 'Creams & Moisturizers', 'Cups', 'Curd and Yogurts', 'Dark Chocolates', 'Dessert Mixes', 'Disposal Bags and Cramp Relief', 'Dry Fruit Sweets', 'Eggs', 'Energy Bars', 'Energy Drinks', 'Eye lens', 'Eyes', 'Face', 'Face Care', 'Face wash and scrubs', 'Feeding and Teething Needs', 'Flakes', 'Fragrance & Talc', 'Fresh Juices', 'Gift Boxes', 'Gift Hampers', 'Gifts & More', 'Gourmet', 'Gourmet collection', 'Guiltfree', 'Gulab Jamun', 'Gulkand & Paan', 'Gum and Mint', 'Gums & Mint', 'Hair Colour', 'Hair Dryers and Stylers', 'Hair Oils and Serums', 'Hair Removal', 'Hair Styling Gels & Creams', 'Hair Supplements', 'Handwash', 'Healthy Snacking', 'Ice Tea & Kombucha', 'Intimate Wipes and Wash', 'Juices and Fruit Drinks', 'Kaju Katli & Barfi', 'Kids Cereals', 'Kulfi', 'Kunafa Chocolate', 'Ladoos', 'Lassi and Buttermilk', 'Lip care', 'Lips', 'Makhana & Dry Fruits', 'Mango Drinks', 'Marie & Digestive', 'Masks & Cleansers', 'Mens Perfume', 'Menstrual Cups and Tampons', 'Milk', 'Milk Based Drinks', 'Milk Chocolates', 'Milkshakes and More', 'Millets & Daliya', 'Mom Care', 'Muesli & Granola', 'Multi groomers', 'Mysore Pak', 'Nachos', 'Nails', 'Oats', 'Oral care', 'Other Flours', 'Paan and Mouth Fresheners', 'Pancake Mixes', 'Paneer and Tofu', 'Peanut Butters', 'Pedhas', 'Period Panties and Liners', 'Poha & Puffed Rice', 'Popcorn', 'Premium', 'Premium Brands', 'Rajma, Chola and Others', 'Rare Finds', 'Rasgulla', 'Rasmalai', 'Ready Mixes', 'Real Fruit', 'Regional Favorites', 'Rice', 'Roll on', 'Rusk', 'Salted & Plain', 'Sanitary Pads', 'Seeds and trail Mixes', 'Serums, Toners', 'Shampoo', 'Shared Packs', 'Shower gel', 'Soaps', 'Soda and Mixers', 'Soft Drinks', 'Sticks', 'Sunscreen', 'Syrups', 'Tools & Brushes', 'Toor, Moong and Urad', 'Travel Needs & Baby Gears', 'Tubs & Party Packs', 'Wafers', 'Water and Ice Cubes', 'Womens Perfume']
#
# Are the subcategory values identical?
# False

# %%
dep1 = set(df1['department'].dropna().unique())
dep2 = set(df2['department'].dropna().unique())

print("Departments only in df1:")
print(sorted(dep1 - dep2))

print("\nDepartments only in df2:")
print(sorted(dep2 - dep1))

print("\nCommon departments:")
print(sorted(dep1 & dep2))

print("\nAre the department values identical?")
print(dep1 == dep2)
# Out:
# Departments only in df1:
# []
#
# Departments only in df2:
# []
#
# Common departments:
# ['Atta, Rice & Dal', 'Baby Care', 'Bakery & Biscuits', 'Beauty & Cosmetics', 'Cold Drinks & Juices', 'Dairy & Breakfast', 'Munchies', 'Personal Care', 'Sweet Tooth']
#
# Are the department values identical?
# True

# %%
brand1 = set(df1['brand_name'].dropna().unique())
brand2 = set(df2['brand_name'].dropna().unique())

print("Brands only in df1:")
print(sorted(brand1 - brand2))

print("\nBrands only in df2:")
print(sorted(brand2 - brand1))

print("\nCommon brands:")
print(sorted(brand1 & brand2))

print("\nAre the brand values identical?")
print(brand1 == brand2)
# Out:
# Brands only in df1:
# ['24BITES', '28 BLACK', '41foods', '5minutes', '7SUN', 'A One Fresh', 'A-1 Chips', 'A2B', 'A2MATE', 'AANCHAL', "AB'S", 'AISHWARYA‘s', 'AJJIMANE', 'AL UZAIR', 'AMARA organic period care', 'ANGUR', 'ANUA', 'AQUAFRESH', 'ARAWALI', 'ARLA', 'ARTOS', 'Aachi', 'Aaha', 'Aavin', 'Abena', 'Abu Haami', 'Acme Poshan', 'ActivHippy', 'Adityaa Milk', 'Adya', 'Adya dairy', "Agrawal's 420 Bites", 'Aishwarya rice', 'Ajmi', 'Alba', 'Alepa Farm', 'Alive & Well', 'Almarai', 'Almond House', 'Alpha 8', 'Amalgama', 'Aman', 'Amar', "Ammamma's", 'Anil', 'Anothr', 'Appeatoz', 'Apple Foods', 'Aqueria', 'Arizona', 'Ark Collectives', 'Arokya', 'Aroma', 'Artisanal', 'Artisante', 'Arun', 'Asal', 'Asha', 'Ashtekar', 'Aswins', 'Auric', 'BAB LOUIE & CO.', 'BAHUBOLI EGGS', 'BAKEMATE', 'BAKERY B', 'BARKLEYS', 'BEN and JERRYS', 'BHADRESWAR', 'BHARAT KRISHNA BAKERS', 'BHARAT KRISHNA BAKERY', 'BIBS', 'BLISSNATURAL', 'BONGO BHOG', 'BOR NOI', 'BOYO', 'BPOP', 'Baa Brew', 'Baana', 'BabyChakra', 'Babysafehouse', 'Baidyanath', 'Bailley', 'Bakeats', 'Baked Bliss', 'Baken Brown', 'Bakerica', 'Bakers', 'Bakers Bunch', 'Bakers World', 'Bakewills', 'Banana Boat', 'Bar One', 'Barefruit', 'Batter Box', 'Beast Life', 'BeatXP', 'Being Punjabi', 'Bengal Baskets', 'Better Food Factory', 'Bhagirathi', 'Bhagyalakshmi', 'Bhanu', 'Bhujamal', 'Big Mishra', 'Bikaneri Basket', 'Biore Men', 'Bisk Farm', 'Blenders Pride', 'Blue Diamond', 'Boba Bhai Ice Creams', 'Bobs Red Mill', 'BodyArmor Lyte', 'Bon fiction', 'Bonco Chocolates', 'Bonvie', 'Bovonto', 'Brainsmith', 'Bran-O', 'Breadberry', 'Brightcrop', 'Brijwasi Sweets', 'Brik Oven', 'Brown Bear', 'Brozeet Ls', 'Bubble Gut', 'Bubble Me', 'Bubz', 'Budhani Bros', 'Buds & Berries', 'CGG Cosmetics', 'CHASKAAH', 'CHIPO', 'CHIZZPA', 'CHOCO TWIGS', 'CHOCOBLAST', 'CLARUS', 'CRANE BETEL NUT', 'Cafe Niloufer', 'Calbee', 'California Skin+', 'Callebaut', 'Candy Can', 'Caprice', 'Cello', 'Chai Point', 'Chak Now', 'Chestnuts', 'Chetrans', 'Chhaswala', 'Chigy Wooh', 'Chitale Dairy', 'Choc Choco', 'Choc Coin', 'Chopard', 'Chukde', 'City Bakery', 'Clamy', 'Cloud9', 'Cochin Snacks', 'Coco Panda', 'Cocoburst', 'CoffeeJoy', 'Cookmaid', 'Coriminic', 'Country Harvest', 'Craze Biscuit', 'Crazybean', 'Cream Stone Tubz', 'Cremberie', 'Cremeux', "D'Acne", 'DESSERTS N MORE', 'DEWELLA', 'DODLA DAIRY', 'DRIX', 'DRUK', 'Daintys', 'Dairy Day', 'Dairy Day Ice Creams & Frozen Desserts', 'Dammani', 'Danbro', 'Darling Masala', 'Davat', 'David Beckham', 'Dayspring', 'De Besto', 'DeBelle', 'Deccan Stone Mills', 'Deccanmudra', 'Delfrez', 'Delicious', 'Denish', 'DentoShine', 'Depiwhite', 'Derma+', 'Desire', 'Dev Snacks', 'Dharishah Ayurveda', 'DiabeSmart', 'Diabic.Fit', 'Dilranjan', "Dinshaw's", 'Dolocold', 'Doobidoo', 'Double Deer', "Dr Teal's", 'Duke', 'ENLITE', 'Ecover', 'Egg First', 'Eggon Eggs', 'Eggstra Fresh', 'Elanadu', 'Elite', 'Elsenz', 'Enafix', 'Ethiglo', 'Evaara Fragrance', 'FFG FARMS', 'FINO', 'FIORELLA', 'FITNEST', 'FOODEAZ', 'FORTUNE Shub Labh', 'FUNC', 'Falero', 'Fang Oral Care', 'Farm Express', 'Farmhouse foods white eggs', 'FarrmB', 'Feals', 'Feel Good Club', 'Firangi Mithai Bakery', 'Fire Beast', 'FixupHealth', 'Flaveo', 'Floryo', 'Flour & Beans', 'Fresh Choice', 'Fresh Eggs', 'FreshLuxe', 'Fresham', 'Freshen', "Freshey's", 'Frissly Organics', 'Fruitchill', 'Fruitoholic', 'G Pulla Reddy Sweets', 'GLIDER', 'GN 1917', 'GNB 365', 'GOONDA ENERGY', 'GOPAL', 'GOPAL NAMKEEN', 'GOPAL WAFERS', 'GRAH LAXMI', 'GRB TOWNBUS', 'GTS Original', 'GUBGUB', 'Gaay Chhap', 'Gajanan', 'Gajraj', 'Gallons', 'Ganesh', 'Gangwal', 'Gatti Fit', 'Gharsa Foods', 'Glori', 'Glucovita', 'Go Grub', 'Go Nuts', 'Goa Dairy', 'Gokul', 'Golden Bite', 'Gone Mad', 'Good Bakery', 'Good Morning', 'Gourmet Staples', 'Grain2Grind', 'Green Milk Concepts', 'Gulabs', 'Guliyan', 'Gurujee Namkeen', 'Gwalia', 'Gyan', 'HALLIMANE', 'HANGYO', 'HAOLIYUAN', 'HASK', 'HENGG', 'HOMA', 'HOMEFILLS', 'HOPPIN', 'HOT CAKES', 'Haagen Dazs', 'Habibs Orgamatics', 'Habit', 'Haeal', 'Hair Drama Co', 'HappieGut Kefir', 'Happinest ...
#
# Brands only in df2:
# ['ARNOTTS TIM TAM', 'Afnan', 'Alokam Sattvam', 'Amayu', 'Bilasure M Kid', 'Bioré', 'Boca', 'Bold Man', 'Bon Amour', 'Brain Blasterz', 'Bregano', 'Bro Zedex', 'CAMAY', 'CIR', 'Ceriz', 'CocoMood', 'Coke', 'Creme Castle', 'DRAGON KING', 'Denzuu', 'Dodoni', 'Doowee Donut', 'Embarouge', "Everyday's Eggs", 'Ez Chef’s', 'ForKids', 'Hakuna', 'Haldiram Bhujiawala', 'Harish', 'Hyalugel', 'Innovitoy', 'Jayanti', 'KIT KAT', "Kaveri's Kitchen", 'Krizvo', 'Lasma', 'Levosiz M', 'MANIA', 'Malloz Pops', 'Miraj', "Mohun's", 'Montecip', 'Montina', 'Montina L', 'Mr. Yolk Marketing Private Limited', 'Mulberry', 'Must be Nuts', 'Nano Basmati Rice', 'Naturoz', 'Neude', 'Oaken Glow', 'Ocean Spray', 'P.Calm', 'Paancho', 'Paushtaa', 'Pigeon By Stovekraft', 'Redbull + Doritos', 'Relow', 'SP', 'ST Blossom', 'STARBUCKS', 'Satmola', 'Shakuntlam', 'Shree Ram Papad', 'Sindhi Dry Fruits', 'Sita Ram Diwan Chand', 'Soventus', 'Spoilt', 'Sri Gomatruka', 'Sumo L Plus', 'Supergrub', 'THINKFLOUR', 'Tastee', 'Tec Tavakkal', 'To Be Honest', 'Toastie Breakfast Town', 'TruVitals', 'TurtleBee', 'Twiddles by Yuvraj Singh', 'VENZ', 'Vantej', 'Voiish', 'Wheatkart', 'Yoku Snacks', 'Zazzy', 'entisi', 'mia&j']
#
# Common brands:
# ['10X', '10on10foods', '1st Step', '24 Mantra', '2OOLS', '2PM Snacks', '3 Sisters', '4700BC', '7 Diamonds', '7up', '8AM', '921', 'A.G. Barr', 'ADIGO', 'AMERICANA', 'AMRIT KRISHI', 'AMRUTH RAJ', 'AND', 'AQUATEIN', 'ARKS', 'AS-IT-IS Nutrition', 'ASIAN GRACE', 'AUSHA', 'AWENEST', 'Aakash', 'Aashirvaad', 'Aashirvaad Namma Chakki', 'Aava', 'Aazol', "Abbie's", 'Abest', 'Abhi Eggs', 'Absolut', 'Ace Blend', 'Acmed', 'Acmist', 'Acnestar', 'Acqua Panna', 'Act II', 'Adidas', 'Adilqadri', 'Aditi Toys', 'Adrenaline Rush', 'Aeroplane Rice', 'Aesthetic Nutrition', 'Agapi', 'Agaro', 'Aggarwal Namkeen', 'Agnee', "Agrawal's 420", 'Ahaar', 'Ahaglow', 'Ajmal', 'Akind', 'Akshayakalpa', 'Akshayakalpa Organic', 'Alerid', 'Alex', 'Alfaparf milano', 'Alife', 'Alkof', 'Allter', 'Almond Roca', 'AloFrut', 'Aloha!', 'Alpenliebe', 'Alpino', 'Altoids', 'Ambrodil S', 'American Garden', 'American Pancake Co', 'Americano', "Amma's Special", 'Amor', 'Amrox', 'Amrox Junior', 'Amrutanjan', 'Amul', 'Amulya', 'Anand', 'Anand Sweets', 'Ananda', 'Ananya', 'Anchor', 'Andaah', 'Andros', 'Anmol', 'Anomaly', 'Anveshan', 'Appy', 'Apsara Ice Creams', 'Aptagrow', 'Aptamil', 'Aquacolor', 'Aquafina', 'Aqualens', 'Aqualogica', 'Aramusk', 'Arata', 'Aravalli', 'Aravi Organic', 'Archies', 'Aroma Care', 'Aroma Magic', 'Aroma Treasures', 'Aromatique', 'Arora', 'Arth', 'Artinci', 'Artiste', 'Asaya', 'Ascoril', 'Ascoril D', 'Ascoril Ls', 'Asthakind', 'Asthakind Dx', 'Atarax', 'Atmosphere Studio', 'Atogla', 'Attar Ayurveda', 'Atulya', 'Aveeno', 'Aveeno Baby', 'Avimee Herbal', 'Avolt', 'Avvatar', 'Awsum', 'Axe', 'Axis-Y', 'Azah', 'B FIZZ', 'B Natural', 'B.O.B.I.', 'B4 Nappi', 'BABUS LAXMINARAYAN', 'BACARDI', 'BACI', 'BANSIWALA', 'BATOOK', 'BB BHARAT BAZAAR', 'BBLUNT', 'BCA', 'BETTER NUTRITION', 'BLA BLI BLU', 'BLND', 'BOBA KINGS', 'BOBBI BROWN', 'BOMBAY 99', 'BOMBAY BANTA', 'BRB', 'BRITVIC', 'BRYAN & CANDY', 'BSY NONI', 'BTS', 'BTW', 'Baba', 'Babio', 'Baby Dove', 'Baby Forest', 'Baby Sebamed', 'BabyGo', 'BabyOrgano', 'BabyPro', 'BabyVerse', 'Babygesic', 'Backbay', "Bagrry's", 'Baileys x SMOOR', 'Bajaj', 'Bajaj Sk', 'Bakelite', "Baker's Loaf", 'Balaji', 'Ballantines', 'Bambo Nature', 'Banderas', 'Banner & Co', 'Bare Anatomy', 'Bare Essentials', 'Bare Necessities', "Barken's", 'Barquillo', 'Barr', 'Barsana Magic', 'Bartisans', 'Baskin Robbins', 'Batwheels', 'Bauli', 'Bazana', 'Bazooka', 'Be Bodywise', 'Be Neude', 'Beaba', 'Beanly', 'Beardhood', 'Beardo', 'Beautiliss Professional', 'Beauty Secrets', 'Beauty of Joseon', 'Beautywise', 'Bebe Burp', 'Beco', 'BeeBaby', 'Beefeater', 'Being Bania', 'Bella', 'BellaVita', 'Benzac', 'Betty Crocker', 'Beyond Snack', 'Beyond Water', 'Bharat Organics', 'BharatRohan', 'Bhikharam Chandmal', 'Bhujialalji', 'Bianca', 'Big Babol', 'Big Snack', 'Bigen', 'Bika', 'Bikaji', 'Bikano', 'Biluma', 'Bin Bin', 'Bindu', 'Bingo', 'Bio Code', 'Bio Nutrients', 'Bio Oil', 'Biodance', 'Bioderma', 'Biolage', 'Biotique', 'Biscrunch', 'Biskitop', 'Bisleri', 'Black & White', 'Bloody', 'Bloom by Bold Care', 'Blossom Kochhar', 'Blue Bird', 'Blue Heaven', 'Blue Nectar', 'Blue Tokai', 'Blur India', 'Boba Bhai', 'Bodify', 'Body Cupid', 'Boho Botanist', 'Bolas', 'Bolt', 'Bombae', 'Bombay Shaving Company', 'Bombucha', 'Bonn', 'Bonomi', 'Bontress', 'Boomer', 'Boost', 'Booster', 'Boroline', 'Boroplus', 'Borécha', 'Botanic Hearth', 'Bounty', 'Brahmins', 'Brillare', 'Britannia', 'Britannia Better Snack Co.', 'Brocode', 'Bronson Professional', 'Brown & Polson', 'Brozeet', 'Bru', 'Budweiser', 'Bullion Mouth Freshner', 'Bumberry', 'Bumtum', 'Burberry', 'Burrf', 'Butlers', 'By Nature', 'CARMEX', 'CHINI KUM', 'CHOSEN', 'CHUDAMANI', 'CHUTNEFY', 'COCO FRUT', 'COCOAMelts', 'COCOHIGH', 'CONFECT', 'CONFECT CAKE DECOR', 'CONTRABAND', 'COSMIX', "COTE D'OR", 'Cadbury', 'Cadbury (Imported)', 'Cadbury Bournvita', 'Cadbury Oreo', 'Cadbury Studio', 'Cadiveu', 'CakeZone', 'Caketale', 'CaliBar', 'Call Me Chunky', 'Calpol', 'Calvin Klein', 'Candid', 'Candycop', 'Candyman', 'Cantina Mexicana', 'Canyon Green ...
#
# Are the brand values identical?
# False

# %%
city1 = set(df1['city'].dropna().unique())
city2 = set(df2['city'].dropna().unique())

print("Cities only in df1:")
print(sorted(city1 - city2))
print(len(city1 - city2))

print("\nCities only in df2:")
print(sorted(city2 - city1))
print(len(city2 - city1))

print("\nCommon cities:")
print(sorted(city1 & city2))
print(len(city1 & city2))

print("\nAre the city values identical?")
print(city1 == city2)
# Out:
# Cities only in df1:
# ['Ahmedabad', 'Ajmer', 'Amravati', 'Bangalore', 'Bhubaneswar', 'Chennai', 'Coimbatore', 'Danapur', 'Faridabad', 'Ghaziabad', 'Guntur', 'Guwahati', 'Hyderabad', 'Indore', 'Jaipur', 'Kochi', 'Kolkata', 'Kollam', 'Kozhikode', 'Latur', 'Lucknow', 'Mapusa', 'Mumbai', 'Muzaffarpur', 'Mysuru', 'Nandivaram Guduvancheri', 'Nashik', 'New Town', 'Nizamabad', 'Noida', 'Ongole', 'Patna', 'Porvorim', 'Puducherry', 'Pune', 'Rudrapur', 'Silchar', 'Surat', 'Trivandrum', 'Varanasi', 'Vasai Virar', 'Vellore', 'Vijayawada', 'Vizianagaram', 'Warangal']
# 45
#
# Cities only in df2:
# []
# 0
#
# Common cities:
# ['Delhi', 'Gurgaon']
# 2
#
# Are the city values identical?
# False

# %%
df2['brand_name'].isnull().sum()
# Out:
# 195

# %%
# Convert to numeric (if they are stored as strings)
df2['promo_offer_price'] = pd.to_numeric(df2['promo_offer_price'], errors='coerce')
df2['product_price'] = pd.to_numeric(df2['product_price'], errors='coerce')

# Find records where promo_offer_price > product_price
invalid_records = df2[
    (df2['promo_offer_price'].notna()) &
    (df2['product_price'].notna()) &
    (df2['promo_offer_price'] > df2['product_price'])
]

print(invalid_records[['unique_id', 'product_name', 'product_price', 'promo_offer_price']])
print(f"\nNumber of violating records: {len(invalid_records)}")
# Out:
# Empty DataFrame
# Columns: [unique_id, product_name, product_price, promo_offer_price]
# Index: []
#
# Number of violating records: 0

# %%
# Treat NaN and empty strings as empty
price_exists = (
    df2['promo_offer_price'].notna() &
    (df2['promo_offer_price'].astype(str).str.strip() != '')
)

desc_exists = (
    df2['promo_offer_description'].notna() &
    (df2['promo_offer_description'].astype(str).str.strip() != '')
)

# One exists, the other doesn't (XOR)
invalid_records = df2[
    price_exists ^ desc_exists
]

print(invalid_records[
    ['unique_id', 'promo_offer_price', 'promo_offer_description']
])
# Out:
# Empty DataFrame
# Columns: [unique_id, promo_offer_price, promo_offer_description]
# Index: []

# %%
invalid = df2[
    df2['product_image_urls'].isna() |
    (df2['product_image_urls'].astype(str).str.strip() == '')
]

print(invalid[['unique_id', 'product_image_urls']])
# Out:
# Empty DataFrame
# Columns: [unique_id, product_image_urls]
# Index: []

# %%
# Length of product names (excluding leading/trailing spaces)
name_length = df2['promo_offer_description'].fillna('').str.strip().str.len()

# Define thresholds
MIN_LENGTH = 5
MAX_LENGTH = 10

# Find invalid product names
invalid_promo = df2[
    (name_length < MIN_LENGTH) |
    (name_length > MAX_LENGTH)
]

print(f"Number of invalid promo descriptions: {len(invalid_promo)}")

print(
    invalid_promo[
        ['unique_id', 'promo_offer_description', 'product_url']
    ].assign(name_length=name_length.loc[invalid_promo.index])
)
# Out:
# Number of invalid promo descriptions: 0
# Empty DataFrame
# Columns: [unique_id, promo_offer_description, product_url, name_length]
# Index: []

# %%
field = 'brand_name'  # Replace with the field you want to check
empty_field_records = df2[
    # df2[field].isna() 
    # |
    # (df2[field].astype(str).str.strip() == '')
    (df2['item_selling_price'] != df2['product_price']) 
   
]

# Print unique_id and pdp_url
print(empty_field_records[[ 'item_mrp', 'item_selling_price', 'product_price', 'promo_offer_price', 'unique_id', 'product_url']])
# Out:
# Empty DataFrame
# Columns: [item_mrp, item_selling_price, product_price, promo_offer_price, unique_id, product_url]
# Index: []
